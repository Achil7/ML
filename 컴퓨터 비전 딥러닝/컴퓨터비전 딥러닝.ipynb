# %% [markdown]
# ### 합성곱  신경망

# %%
# cnn 
# 컨브넷
# 28, 28 , 1
import tensorflow as tf
from tensorflow.keras import layers
inputs = tf.keras.Input(shape = (28,28,1))
conv = layers.Conv2D(32,(3,3), activation='relu')(inputs)
conv = layers.MaxPooling2D()(conv)
conv = layers.Conv2D(64,(3,3), activation ='relu')(conv)
conv = layers.MaxPooling2D()(conv)
conv = layers.Conv2D(128,(3,3), activation ='relu')(conv)

# %%
flatlayer = layers.Flatten()(conv)
outputs =  layers.Dense(10,activation='softmax')(flatlayer)

# %%
model = tf.keras.Model(inputs = inputs, outputs = outputs)

# %%
# model.summary()
tf.keras.utils.plot_model(model,show_shapes=True)

# %%
# 데이터 준비하기
# MNIST 이미지
from tensorflow.keras.datasets import mnist
import numpy as np

# %%
(x_train,y_train),(x_test,y_test) =  mnist.load_data()
# convolution은 3차원 텐서이기 때문에 차수를 맞춰준다.
x_train = np.expand_dims(x_train,axis = -1)
x_test = np.expand_dims(x_test,axis = -1)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
# 데이터 스케일링
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# %%
model.compile(optimizer='adam',loss=tf.keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])
model.fit(x_train,y_train,epochs=5,batch_size=64)
# Out:
# Epoch 1/5
# 938/938 [==============================] - 15s 4ms/step - loss: 0.1695 - accuracy: 0.9490
# Epoch 2/5
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0472 - accuracy: 0.9855
# Epoch 3/5
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0332 - accuracy: 0.9888
# Epoch 4/5
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0248 - accuracy: 0.9923
# Epoch 5/5
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0196 - accuracy: 0.9938

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0285 - accuracy: 0.9915
# [0.028462447226047516, 0.9915000200271606]

# %% [markdown]
# #### 폴링층의누락

# %%
conv2 = layers.Conv2D(32,(3,3),activation='relu')(inputs)
conv2 = layers.Conv2D(64,(3,3),activation='relu')(conv2)
conv2 = layers.Conv2D(128,(3,3),activation='relu')(conv2)
conv2 = layers.Flatten()(conv2)
outputs = layers.Dense(10,activation='softmax')(conv2)
model2 = tf.keras.Model(inputs=inputs,outputs=outputs)

# %%
tf.keras.utils.plot_model(model2)

# %%
model2.compile(optimizer='adam',loss=tf.keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])
model2.fit(x_train,y_train,epochs=5,batch_size=64)
model2.evaluate(x_test,y_test)
# Out:
# Epoch 1/5
# 938/938 [==============================] - 8s 8ms/step - loss: 0.1157 - accuracy: 0.9654
# Epoch 2/5
# 938/938 [==============================] - 8s 8ms/step - loss: 0.0405 - accuracy: 0.9873
# Epoch 3/5
# 938/938 [==============================] - 8s 8ms/step - loss: 0.0251 - accuracy: 0.9923
# Epoch 4/5
# 938/938 [==============================] - 8s 9ms/step - loss: 0.0176 - accuracy: 0.9943
# Epoch 5/5
# 938/938 [==============================] - 8s 8ms/step - loss: 0.0115 - accuracy: 0.9963
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0449 - accuracy: 0.9869
# [0.04485663026571274, 0.9868999719619751]

# %% [markdown]
# #### 작은 데이터셋 문제에서 딥러닝의 타당성

# %%
# !pip install gdown

# %%
import gdown
gdown.download(id='18uC7WTuEXKJDDxbj-Jq6EjzpFrgE7IAd', output='dogs-vs-cats.zip')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=18uC7WTuEXKJDDxbj-Jq6EjzpFrgE7IAd
# To: /content/dogs-vs-cats.zip
# 100%|██████████| 852M/852M [00:11<00:00, 76.9MB/s]
# 'dogs-vs-cats.zip'

# %%
# import zipfile

# %%
# !unzip -qq 'dogs-vs-cats.zip'

# %%
# !unzip -qq 'train.zip'
# !unzip -qq 'test1.zip'

# %% [markdown]
# #### 이미지를 훈련,검증,테스트 디렉터리로 복사

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("cats_vs_dogs_small")

# %%
original_dir, new_base_dir
# Out:
# (PosixPath('train'), PosixPath('cats_vs_dogs_small'))

# %%
def make_subset(subset_name, start_index, end_index):
    for category in ('cat', 'dog'):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [ f"{category}.{i}.jpg" for i in range(start_index,end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir/fname, dst=dir/fname)

# %%
make_subset("train", start_index=0, end_index=1000)

# %%
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

# %% [markdown]
# ### 데이터 전처리  이미지 데이터를 수치형으로 변환

# %%
from tensorflow.keras.utils import image_dataset_from_directory
new_base_dir
# Out:
# PosixPath('cats_vs_dogs_small')

# %%
train_dataset =  image_dataset_from_directory(
    new_base_dir/"train"    
)
validation_dataset =  image_dataset_from_directory(
    new_base_dir/"validation"    
)
test_dataset =  image_dataset_from_directory(
    new_base_dir/"test"    
)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
import numpy as np
import tensorflow as tf
random_numbers =  np.random.normal(size=(1000,16))
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)

# %%
len(dataset)
# Out:
# 1000

# %%
for i, element in enumerate(dataset):
    if i > 2: break
    print(element.shape)
# Out:
# (16,)
# (16,)
# (16,)

# %%
batch_dataset =  dataset.batch(32)
for i, element in enumerate(batch_dataset):
    if i>2 : break
    print(element.shape)
# Out:
# (32, 16)
# (32, 16)
# (32, 16)

# %%
reshape_dataset =  dataset.map(lambda x: tf.reshape(x, (4,4)))
for i, element in enumerate(reshape_dataset):
    if i>2 : break
    print(element.shape)
# Out:
# (4, 4)
# (4, 4)
# (4, 4)

# %% [markdown]
# #### dataset이 반환하는 데이터와 레이블 크기 확인

# %%
for data_batch, labels_batch in train_dataset:
    print("데이터 배치 크기:", data_batch.shape)
    print("레이블 배치 크기:",labels_batch.shape)
    break
# Out:
# 데이터 배치 크기: (32, 256, 256, 3)
# 레이블 배치 크기: (32,)

# %% [markdown]
# #### 모델 만들기

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
inputs = keras.Input(shape=(256, 256, 3))
x = layers.Rescaling(1/255.0)(inputs)
x = layers.Conv2D(32,(3,3),activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(64,(3,3),activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(128,(3,3),activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(256,(3,3),activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(256,(3,3),activation='relu')(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1,activation='sigmoid')(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath='convert_from_scratch.keras',
        save_best_only=True,
        monitor = 'val_loss'
    )
]

# %%
hist = model.fit(train_dataset,epochs=30,validation_data=validation_dataset,callbacks=callbacks)
# Out:
# Epoch 1/30
# 63/63 [==============================] - 11s 145ms/step - loss: 0.6913 - accuracy: 0.5085 - val_loss: 0.6645 - val_accuracy: 0.5980
# Epoch 2/30
# 63/63 [==============================] - 8s 123ms/step - loss: 0.6562 - accuracy: 0.5850 - val_loss: 0.7304 - val_accuracy: 0.5690
# Epoch 3/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.6337 - accuracy: 0.6385 - val_loss: 0.6585 - val_accuracy: 0.5880
# Epoch 4/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.6251 - accuracy: 0.6440 - val_loss: 0.6173 - val_accuracy: 0.6460
# Epoch 5/30
# 63/63 [==============================] - 11s 173ms/step - loss: 0.5973 - accuracy: 0.6740 - val_loss: 0.6315 - val_accuracy: 0.6170
# Epoch 6/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.5788 - accuracy: 0.6995 - val_loss: 0.5869 - val_accuracy: 0.6820
# Epoch 7/30
# 63/63 [==============================] - 8s 117ms/step - loss: 0.5421 - accuracy: 0.7320 - val_loss: 0.5793 - val_accuracy: 0.6820
# Epoch 8/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.5119 - accuracy: 0.7500 - val_loss: 0.5722 - val_accuracy: 0.6950
# Epoch 9/30
# 63/63 [==============================] - 8s 116ms/step - loss: 0.5305 - accuracy: 0.7320 - val_loss: 0.5741 - val_accuracy: 0.7100
# Epoch 10/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.4720 - accuracy: 0.7800 - val_loss: 0.5888 - val_accuracy: 0.7040
# Epoch 11/30
# 63/63 [==============================] - 8s 119ms/step - loss: 0.4284 - accuracy: 0.7955 - val_loss: 0.5910 - val_accuracy: 0.7130
# Epoch 12/30
# 63/63 [==============================] - 8s 116ms/step - loss: 0.3775 - accuracy: 0.8305 - val_loss: 0.6327 - val_accuracy: 0.7090
# Epoch 13/30
# 63/63 [==============================] - 8s 117ms/step - loss: 0.3412 - accuracy: 0.8465 - val_loss: 0.6829 - val_accuracy: 0.7280
# Epoch 14/30
# 63/63 [==============================] - 8s 123ms/step - loss: 0.2616 - accuracy: 0.8840 - val_loss: 0.7357 - val_accuracy: 0.7280
# Epoch 15/30
# 63/63 [==============================] - 8s 117ms/step - loss: 0.1988 - accuracy: 0.9210 - val_loss: 0.9240 - val_accuracy: 0.7070
# Epoch 16/30
# 63/63 [==============================] - 8s 116ms/step - loss: 0.1725 - accuracy: 0.9295 - val_loss: 1.0567 - val_accuracy: 0.7240
# Epoch 17/30
# 63/63 [==============================] - 8s 117ms/step - loss: 0.1089 - accuracy: 0.9595 - val_loss: 1.4342 - val_accuracy: 0.6970
# Epoch 18/30
# 63/63 [==============================] - 8s 117ms/step - loss: 0.1179 - accuracy: 0.9530 - val_loss: 1.2337 - val_accuracy: 0.7120
# Epoch 19/30
# 63/63 [==============================] - 8s 117ms/step - loss: 0.0600 - accuracy: 0.9790 - val_loss: 1.4785 - val_accuracy: 0.7210
# Epoch 20/30
# 63/63 [==============================] - 8s 117ms/step - loss: 0.0438 - accuracy: 0.9840 - val_loss: 1.8812 - val_accuracy: 0.6860
# Epoch 21/30
# 63/63 [==============================] - 8s 117ms/step - loss: 0.1138 - accuracy: 0.9575 - val_loss: 1.5082 - val_accuracy: 0.7070
# Epoch 22/30
# 63/63 [==============================] - 8s 117ms/step - loss: 0.0736 - accuracy: 0.9710 - val_loss: 1.4880 - val_accuracy: 0.7290
# Epoch 23/30
# 63/63 [==============================] - 8s 117ms/step - loss: 0.0355 - accuracy: 0.9855 - val_loss: 1.7936 - val_accuracy: 0.6820
# Epoch 24/30
# 63/63 [==============================] - 8s 117ms/step - loss: 0.0514 - accuracy: 0.9825 - val_loss: 1.7947 - val_accuracy: 0.6890
# Epoch 25/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.0253 - accuracy: 0.9915 - val_loss: 1.8785 - val_accuracy: 0.7020
# Epoch 26/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.0062 - accuracy: 0.9985 - val_loss: 1.9531 - val_accuracy: 0.7310
# Epoch 27/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.0617 - val_accuracy: 0.7330
# Epoch 28/30
# 63/63 [==============================] - 8s 117ms/step - loss: 8.3787e-04 - accuracy: 1.0000 - val_loss: 2.1410 - val_accuracy: 0.7370
# Epoch 29/30
# 63/63 [==============================] - 8s 117ms/step - loss: 5.8298e-04 - accuracy: 1.0000 - val_loss: 2.1972 - val_accuracy: 0.7380
# Epoch 30/30
# 63/63 [==============================] - 8s 117ms/step - loss: 4.4001e-04 - accuracy: 1.0000 - val_loss: 2.2462 - val_accuracy: 0.7340

# %% [markdown]
# ### 훈련 정확도와 손실 그래프 그리기

# %%
from numpy.random.mtrand import exponential
import matplotlib.pyplot as plt
accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(1,len(accuracy)+1)
plt.plot(epochs, accuracy, 'bo',label='Training accuracy')
plt.plot(epochs, val_accuracy, 'r',label='Validation accuracy')
plt.title('Training and validation acuuracy')
plt.legend()
plt.figure()
plt.plot(epochs,loss,'bo', label = 'Traianing loss')
plt.plot(epochs,val_loss,'r', label = 'Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ### 오버핏

# %%
test_model = keras.models.load_model('convert_from_scratch.keras')
test_loss, test_acc = test_model.evaluate(test_dataset)
test_loss, test_acc
# Out:
# 63/63 [==============================] - 4s 56ms/step - loss: 0.5918 - accuracy: 0.7010
# (0.5918382406234741, 0.7009999752044678)

# %%
test_loss, test_acc
# Out:
# (0.5918382406234741, 0.7009999752044678)

# %% [markdown]
# ### 데이터 증식기 이용
# 컨볼루션에 추가할 데이터 증식 단계 정의

# %%
data_agumentation = keras.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2)
])

# %%
plt.figure(figsize=(10,10))
for images,_ in train_dataset.take(1):
  plt.imshow(images[0].numpy().astype('uint8'))
  plt.figure()
  for i in range(9):
    new_images = data_agumentation(images)
    ax = plt.subplot(3,3,i+1)
    plt.imshow(new_images[0].numpy().astype('uint8'))
    plt.axis('off')

# %% [markdown]
# ### 이미지 증식과 드랍아웃을 포함한 컨볼루션

# %%
inputs = keras.Input(shape=(256, 256, 3))
x = data_agumentation(inputs)
x = layers.Rescaling(1/255.0)(inputs)
x = layers.Conv2D(32,(3,3),activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(64,(3,3),activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(128,(3,3),activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(256,(3,3),activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(256,(3,3),activation='relu')(x)
x = layers.Dropout(0.5)(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1,activation='sigmoid')(x)

model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath='convert_from_with_imagesGenerator_scratch.keras',
        save_best_only=True,
        monitor = 'val_loss'
    )
]
hist = model.fit(train_dataset,epochs=30,validation_data=validation_dataset,callbacks=callbacks)
# Out:
# Epoch 1/30
# 63/63 [==============================] - 8s 120ms/step - loss: 0.6964 - accuracy: 0.5135 - val_loss: 0.6950 - val_accuracy: 0.5000
# Epoch 2/30
# 63/63 [==============================] - 8s 119ms/step - loss: 0.6870 - accuracy: 0.5285 - val_loss: 0.6653 - val_accuracy: 0.5800
# Epoch 3/30
# 63/63 [==============================] - 8s 119ms/step - loss: 0.6757 - accuracy: 0.5945 - val_loss: 0.6599 - val_accuracy: 0.5760
# Epoch 4/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.6278 - accuracy: 0.6370 - val_loss: 0.6084 - val_accuracy: 0.7000
# Epoch 5/30
# 63/63 [==============================] - 8s 117ms/step - loss: 0.6031 - accuracy: 0.6705 - val_loss: 0.6183 - val_accuracy: 0.6820
# Epoch 6/30
# 63/63 [==============================] - 8s 117ms/step - loss: 0.5837 - accuracy: 0.7040 - val_loss: 0.6098 - val_accuracy: 0.6840
# Epoch 7/30
# 63/63 [==============================] - 8s 120ms/step - loss: 0.5692 - accuracy: 0.7025 - val_loss: 0.5841 - val_accuracy: 0.7120
# Epoch 8/30
# 63/63 [==============================] - 8s 120ms/step - loss: 0.5321 - accuracy: 0.7370 - val_loss: 0.6256 - val_accuracy: 0.6990
# Epoch 9/30
# 63/63 [==============================] - 8s 121ms/step - loss: 0.4971 - accuracy: 0.7620 - val_loss: 0.5494 - val_accuracy: 0.7380
# Epoch 10/30
# 63/63 [==============================] - 10s 157ms/step - loss: 0.4876 - accuracy: 0.7745 - val_loss: 0.5867 - val_accuracy: 0.7330
# Epoch 11/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.4351 - accuracy: 0.8005 - val_loss: 0.5686 - val_accuracy: 0.7460
# Epoch 12/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.3735 - accuracy: 0.8355 - val_loss: 0.6358 - val_accuracy: 0.7570
# Epoch 13/30
# 63/63 [==============================] - 8s 117ms/step - loss: 0.3380 - accuracy: 0.8505 - val_loss: 0.6175 - val_accuracy: 0.7520
# Epoch 14/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.2816 - accuracy: 0.8760 - val_loss: 0.6549 - val_accuracy: 0.7500
# Epoch 15/30
# 63/63 [==============================] - 8s 117ms/step - loss: 0.2475 - accuracy: 0.8940 - val_loss: 0.7505 - val_accuracy: 0.7550
# Epoch 16/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.1788 - accuracy: 0.9205 - val_loss: 0.7638 - val_accuracy: 0.7580
# Epoch 17/30
# 63/63 [==============================] - 8s 117ms/step - loss: 0.1453 - accuracy: 0.9395 - val_loss: 0.7928 - val_accuracy: 0.7520
# Epoch 18/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.1199 - accuracy: 0.9485 - val_loss: 0.8715 - val_accuracy: 0.7650
# Epoch 19/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.1443 - accuracy: 0.9455 - val_loss: 0.8095 - val_accuracy: 0.7490
# Epoch 20/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.1041 - accuracy: 0.9625 - val_loss: 0.9657 - val_accuracy: 0.7610
# Epoch 21/30
# 63/63 [==============================] - 8s 128ms/step - loss: 0.0973 - accuracy: 0.9615 - val_loss: 0.8841 - val_accuracy: 0.7430
# Epoch 22/30
# 63/63 [==============================] - 8s 119ms/step - loss: 0.0954 - accuracy: 0.9685 - val_loss: 0.8662 - val_accuracy: 0.7700
# Epoch 23/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.0750 - accuracy: 0.9735 - val_loss: 1.1532 - val_accuracy: 0.7390
# Epoch 24/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.0662 - accuracy: 0.9760 - val_loss: 1.0878 - val_accuracy: 0.7600
# Epoch 25/30
# 63/63 [==============================] - 8s 126ms/step - loss: 0.0594 - accuracy: 0.9810 - val_loss: 1.1290 - val_accuracy: 0.7370
# Epoch 26/30
# 63/63 [==============================] - 8s 117ms/step - loss: 0.0631 - accuracy: 0.9790 - val_loss: 1.1529 - val_accuracy: 0.7400
# Epoch 27/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.0360 - accuracy: 0.9880 - val_loss: 1.2068 - val_accuracy: 0.7530
# Epoch 28/30
# 63/63 [==============================] - 8s 119ms/step - loss: 0.0204 - accuracy: 0.9940 - val_loss: 1.3978 - val_accuracy: 0.7620
# Epoch 29/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.0274 - accuracy: 0.9890 - val_loss: 1.6135 - val_accuracy: 0.7230
# Epoch 30/30
# 63/63 [==============================] - 8s 118ms/step - loss: 0.0774 - accuracy: 0.9730 - val_loss: 1.1822 - val_accuracy: 0.7370

# %%
import matplotlib.pyplot as plt
accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(1,len(accuracy)+1)
plt.plot(epochs, accuracy, 'bo',label='Training accuracy')
plt.plot(epochs, val_accuracy, 'r',label='Validation accuracy')
plt.title('Training and validation acuuracy')
plt.legend()
plt.figure()
plt.plot(epochs,loss,'bo', label = 'Traianing loss')
plt.plot(epochs,val_loss,'r', label = 'Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model('convert_from_with_imagesGenerator_scratch.keras')
test_loss, test_acc = test_model.evaluate(test_dataset)
test_loss, test_acc
# Out:
# 63/63 [==============================] - 4s 55ms/step - loss: 0.5868 - accuracy: 0.7200
# (0.5868483185768127, 0.7200000286102295)

# %% [markdown]
# ### 사전훈련된 모델 활용
# VGG16 합성곱 기반 층 만들기

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights = 'imagenet',
    include_top=False,
    input_shape = (256,256,3)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 1s 0us/step

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
import numpy as np
def get_features_and_labels(dataset):
  all_features = []
  all_labels = []
  for images, labels in dataset:
    preprocessed_images = keras.applications.vgg16.preprocess_input(images)
    features = conv_base.predict(preprocessed_images)
    all_features.append(features)
    all_labels.append(labels)
  return np.concatenate(all_features), np.concatenate(all_labels)
  
train_features, train_labels = get_features_and_labels(train_dataset)
val_features, val_labels = get_features_and_labels(validation_dataset)
test_features, test_labels = get_features_and_labels(test_dataset)
# Out:
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step

# %%
train_features.shape, val_features.shape
# Out:
# ((2000, 8, 8, 512), (1000, 8, 8, 512))

# %%
inputs = keras.Input(shape=(8,8,512))
x = layers.Flatten()(inputs)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1,activation = 'sigmoid')(x)
model = keras.Model(inputs,outputs)
model.compile(loss = 'binary_crossentropy', optimizer='adam',metrics=['accuracy'])
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath = 'feature_extraction.keras',
        save_best_only = True,
        monitor = 'val_loss'
    ),
    # keras.callbacks.EarlyStopping(patience = 3)
]
hist = model.fit(
    train_features, train_labels,
    epochs = 20,
    validation_data = (val_features, val_labels),
    callbacks = callbacks
)
# Out:
# Epoch 1/20
# 63/63 [==============================] - 1s 14ms/step - loss: 14.4740 - accuracy: 0.9430 - val_loss: 6.7459 - val_accuracy: 0.9680
# Epoch 2/20
# 63/63 [==============================] - 1s 11ms/step - loss: 2.2524 - accuracy: 0.9865 - val_loss: 6.3187 - val_accuracy: 0.9730
# Epoch 3/20
# 63/63 [==============================] - 1s 8ms/step - loss: 0.9740 - accuracy: 0.9925 - val_loss: 8.3812 - val_accuracy: 0.9700
# Epoch 4/20
# 63/63 [==============================] - 1s 8ms/step - loss: 1.3761 - accuracy: 0.9925 - val_loss: 13.8350 - val_accuracy: 0.9630
# Epoch 5/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.3900 - accuracy: 0.9975 - val_loss: 7.3164 - val_accuracy: 0.9730
# Epoch 6/20
# 63/63 [==============================] - 0s 8ms/step - loss: 0.5090 - accuracy: 0.9980 - val_loss: 7.3184 - val_accuracy: 0.9770
# Epoch 7/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6085 - accuracy: 0.9965 - val_loss: 9.9445 - val_accuracy: 0.9690
# Epoch 8/20
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4116 - accuracy: 0.9950 - val_loss: 13.8825 - val_accuracy: 0.9660
# Epoch 9/20
# 63/63 [==============================] - 1s 9ms/step - loss: 2.7630 - accuracy: 0.9915 - val_loss: 11.1617 - val_accuracy: 0.9730
# Epoch 10/20
# 63/63 [==============================] - 0s 7ms/step - loss: 1.0682 - accuracy: 0.9955 - val_loss: 13.1922 - val_accuracy: 0.9660
# Epoch 11/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.1457 - accuracy: 0.9980 - val_loss: 14.9404 - val_accuracy: 0.9650
# Epoch 12/20
# 63/63 [==============================] - 1s 8ms/step - loss: 1.1046 - accuracy: 0.9955 - val_loss: 11.9254 - val_accuracy: 0.9660
# Epoch 13/20
# 63/63 [==============================] - 1s 8ms/step - loss: 0.7194 - accuracy: 0.9965 - val_loss: 10.4703 - val_accuracy: 0.9770
# Epoch 14/20
# 63/63 [==============================] - 0s 8ms/step - loss: 1.6396 - accuracy: 0.9940 - val_loss: 19.4319 - val_accuracy: 0.9630
# Epoch 15/20
# 63/63 [==============================] - 1s 8ms/step - loss: 0.3902 - accuracy: 0.9985 - val_loss: 15.6483 - val_accuracy: 0.9710
# Epoch 16/20
# 63/63 [==============================] - 1s 8ms/step - loss: 0.7229 - accuracy: 0.9975 - val_loss: 8.1399 - val_accuracy: 0.9740
# Epoch 17/20
# 63/63 [==============================] - 1s 8ms/step - loss: 0.6417 - accuracy: 0.9980 - val_loss: 14.2480 - val_accuracy: 0.9670
# Epoch 18/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.4315 - accuracy: 0.9975 - val_loss: 14.6345 - val_accuracy: 0.9680
# Epoch 19/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.3864 - accuracy: 0.9980 - val_loss: 17.3357 - val_accuracy: 0.9660
# Epoch 20/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 10.3687 - val_accuracy: 0.9780

# %%
from numpy.random.mtrand import exponential
import matplotlib.pyplot as plt
accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(1,len(accuracy)+1)
plt.plot(epochs, accuracy, 'bo',label='Training accuracy')
plt.plot(epochs, val_accuracy, 'r',label='Validation accuracy')
plt.title('Training and validation acuuracy')
plt.legend()
plt.figure()
plt.plot(epochs,loss,'bo', label = 'Traianing loss')
plt.plot(epochs,val_loss,'r', label = 'Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model('feature_extraction.keras')
test_model.evaluate(test_features, test_labels)

#  >> 과적합
# Out:
# 63/63 [==============================] - 0s 4ms/step - loss: 6.8841 - accuracy: 0.9780
# [6.884143352508545, 0.9779999852180481]

# %% [markdown]
# ### 데이터 증식을 사용해서 특성 추출
# vgg 16합성곱 기반 층을 만들고 동결

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights = 'imagenet',
    include_top = False
)
conv_base.trainable = False

# %%
# 동결 하기전과 후의 훈련 가능한 가중치 리스트를 출력
conv_base.trainable = True
print(f'합성곱 기반 층을 동결하기 전의 훈련 가능한 가중치 개수 :',len(conv_base.trainable_weights))
# Out:
# 합성곱 기반 층을 동결하기 전의 훈련 가능한 가중치 개수 : 26

# %%
conv_base.trainable = False
print(f'합성곱 기반 층을 동결 후의 훈련 가능한 가중치 개수 :',len(conv_base.trainable_weights))
# Out:
# 합성곱 기반 층을 동결 후의 훈련 가능한 가중치 개수 : 0

# %%
data_agumentation = keras.Sequential([
        layers.RandomFlip('horizontal'),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2)])
inputs = keras.Input(shape = (256,256,3))
x = data_agumentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1,activation='sigmoid')(x)
model = keras.Model(inputs,outputs)
hist = model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
callbacks=[keras.callbacks.ModelCheckpoint(
    filepath = 'feature_extraction_with_data_augumentation.keras',
    save_best_only=True,
    monitor = 'val_loss')]
hist = model.fit(train_dataset,epochs=10,validation_data=validation_dataset,
                 callbacks = callbacks)
# Out:
# Epoch 1/10
# 63/63 [==============================] - 24s 356ms/step - loss: 12.5200 - accuracy: 0.9165 - val_loss: 5.2210 - val_accuracy: 0.9770
# Epoch 2/10
# 63/63 [==============================] - 22s 350ms/step - loss: 6.0539 - accuracy: 0.9645 - val_loss: 6.5981 - val_accuracy: 0.9720
# Epoch 3/10
# 63/63 [==============================] - 22s 343ms/step - loss: 5.6249 - accuracy: 0.9650 - val_loss: 6.6649 - val_accuracy: 0.9750
# Epoch 4/10
# 63/63 [==============================] - 23s 353ms/step - loss: 3.7668 - accuracy: 0.9790 - val_loss: 5.0541 - val_accuracy: 0.9800
# Epoch 5/10
# 63/63 [==============================] - 23s 355ms/step - loss: 3.2716 - accuracy: 0.9810 - val_loss: 3.9801 - val_accuracy: 0.9820
# Epoch 6/10
# 63/63 [==============================] - 22s 345ms/step - loss: 4.6869 - accuracy: 0.9770 - val_loss: 5.4912 - val_accuracy: 0.9810
# Epoch 7/10
# 63/63 [==============================] - 22s 342ms/step - loss: 2.2701 - accuracy: 0.9830 - val_loss: 4.5397 - val_accuracy: 0.9780
# Epoch 8/10
# 63/63 [==============================] - 22s 349ms/step - loss: 2.2496 - accuracy: 0.9860 - val_loss: 6.7474 - val_accuracy: 0.9770
# Epoch 9/10
# 63/63 [==============================] - 22s 346ms/step - loss: 3.4577 - accuracy: 0.9830 - val_loss: 8.0310 - val_accuracy: 0.9790
# Epoch 10/10
# 63/63 [==============================] - 23s 357ms/step - loss: 2.5027 - accuracy: 0.9855 - val_loss: 4.9896 - val_accuracy: 0.9860

# %%
from numpy.random.mtrand import exponential
import matplotlib.pyplot as plt
accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(1,len(accuracy)+1)
plt.plot(epochs, accuracy, 'bo',label='Training accuracy')
plt.plot(epochs, val_accuracy, 'r',label='Validation accuracy')
plt.title('Training and validation acuuracy')
plt.legend()
plt.figure()
plt.plot(epochs,loss,'bo', label = 'Traianing loss')
plt.plot(epochs,val_loss,'r', label = 'Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model('feature_extraction_with_data_augumentation.keras')
test_model.evaluate(test_dataset)
# Out:
# 63/63 [==============================] - 14s 209ms/step - loss: 5.8263 - accuracy: 0.9825
# [5.826254367828369, 0.9825000166893005]

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# 마지막에서 4번째 층까지 동결
conv_base.trainable = True
for layer in conv_base.layers[:-4]:
  layer.trainable = False

# %%
# 모델 미세 조정
model.compile(loss='binary_crossentropy',optimizer = keras.optimizers.Adam(learning_rate=1e-5),metrics=['accuracy'])
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath = 'fine_tuning.keras',
        save_best_only = True,
        monitor = 'val_loss'
    )
]
hist = model.fit(
    train_dataset,
    epochs = 10,
    validation_data = validation_dataset,
    callbacks = callbacks
)
# Out:
# Epoch 1/10
# 63/63 [==============================] - 26s 380ms/step - loss: 0.9028 - accuracy: 0.9910 - val_loss: 4.9168 - val_accuracy: 0.9850
# Epoch 2/10
# 63/63 [==============================] - 24s 379ms/step - loss: 1.8773 - accuracy: 0.9915 - val_loss: 4.5603 - val_accuracy: 0.9830
# Epoch 3/10
# 63/63 [==============================] - 24s 382ms/step - loss: 1.3277 - accuracy: 0.9925 - val_loss: 4.2146 - val_accuracy: 0.9810
# Epoch 4/10
# 63/63 [==============================] - 23s 367ms/step - loss: 0.6875 - accuracy: 0.9915 - val_loss: 4.9516 - val_accuracy: 0.9770
# Epoch 5/10
# 63/63 [==============================] - 24s 381ms/step - loss: 0.8276 - accuracy: 0.9925 - val_loss: 3.5860 - val_accuracy: 0.9800
# Epoch 6/10
# 63/63 [==============================] - 23s 369ms/step - loss: 0.5694 - accuracy: 0.9940 - val_loss: 3.8597 - val_accuracy: 0.9800
# Epoch 7/10
# 63/63 [==============================] - 23s 367ms/step - loss: 0.2846 - accuracy: 0.9945 - val_loss: 3.8023 - val_accuracy: 0.9800
# Epoch 8/10
# 63/63 [==============================] - 24s 381ms/step - loss: 0.2392 - accuracy: 0.9955 - val_loss: 3.3451 - val_accuracy: 0.9860
# Epoch 9/10
# 63/63 [==============================] - 23s 369ms/step - loss: 0.3969 - accuracy: 0.9945 - val_loss: 3.6231 - val_accuracy: 0.9810
# Epoch 10/10
# 63/63 [==============================] - 24s 374ms/step - loss: 0.3184 - accuracy: 0.9945 - val_loss: 3.9105 - val_accuracy: 0.9790

# %%
test_model = keras.models.load_model('fine_tuning.keras')
test_model.evaluate(test_dataset)
# Out:
# 63/63 [==============================] - 14s 206ms/step - loss: 2.7341 - accuracy: 0.9850
# [2.734138011932373, 0.9850000143051147]
