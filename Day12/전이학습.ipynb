# %%
# 축구를 잘하는 사람이 족구도 잘한다.
# 요리를 잘하는 사람이 라면도 잘 끓인다
# 파이썬을 공부한 사람은 다른 언어를 잘 할 가능성이 많다.

# %%
# 딥러닝에도 적용
# 자연영상으로 학습한 신경망을 새나 개의 종을 분류하거나 자율주행에서 차선과 보행자 인식하는사용
# 어떤 도메인의 데이터로 학습한 모델을 다른 도메인의 데이터를 인식하는데 활용해서 성능 향상을 도모하는 기법
# cub200-2011 : 200종의 새 영상을 가지는데 부류별로 60장 밖에 안되서 과잉적합우려
# ImageNet으로 예비학습된 모델을 cub200-2011로 전이하는 전이학습

# %%
#ImageNet으로 학습된 ResNet50을 cub 데이터셋으로 전이 학습
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten,Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.resnet50 import ResNet50,preprocess_input
from tensorflow.keras.preprocessing import image
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import zipfile
# zippath = "/content/drive/MyDrive/CUB200/CUB200.zip"
# zip_ref = zipfile.ZipFile(zippath,'r')
# zip_ref.extractall('/content/drive/MyDrive/CUB200')  
# zip_ref.close()
# # !unzip -qq "/content/drive/MyDrive/CUB200/CUB200.zip"

# %%
class_reduce = 0.1
train_folder = "/content/drive/MyDrive/IT수업/데이터/CUB200/train"
test_folder = "/content/drive/MyDrive/IT수업/데이터/CUB200/test"

# %%
# 정답의 라벨수(부류의 갯수)
no_class = int(len(os.listdir(test_folder))*class_reduce)
no_class
# Out:
# 20

# %%
import glob
# 현재경로 뿐만 아니라 특정경로의 디렉터리명이나 확장자를 지정하면 해당 파일만
# 가져오는데 절대경로로 가져온다.
glob.glob(train_folder+"/*")
# Out:
# ['/content/drive/MyDrive/IT수업/데이터/CUB200/train/001.Black_footed_Albatross',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/002.Laysan_Albatross',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/003.Sooty_Albatross',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/004.Groove_billed_Ani',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/005.Crested_Auklet',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/006.Least_Auklet',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/007.Parakeet_Auklet',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/008.Rhinoceros_Auklet',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/009.Brewer_Blackbird',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/010.Red_winged_Blackbird',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/011.Rusty_Blackbird',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/012.Yellow_headed_Blackbird',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/013.Bobolink',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/014.Indigo_Bunting',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/015.Lazuli_Bunting',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/016.Painted_Bunting',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/017.Cardinal',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/018.Spotted_Catbird',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/019.Gray_Catbird',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/020.Yellow_breasted_Chat',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/021.Eastern_Towhee',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/022.Chuck_will_Widow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/023.Brandt_Cormorant',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/024.Red_faced_Cormorant',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/025.Pelagic_Cormorant',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/026.Bronzed_Cowbird',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/027.Shiny_Cowbird',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/028.Brown_Creeper',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/029.American_Crow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/030.Fish_Crow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/031.Black_billed_Cuckoo',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/032.Mangrove_Cuckoo',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/033.Yellow_billed_Cuckoo',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/034.Gray_crowned_Rosy_Finch',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/035.Purple_Finch',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/036.Northern_Flicker',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/037.Acadian_Flycatcher',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/038.Great_Crested_Flycatcher',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/039.Least_Flycatcher',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/040.Olive_sided_Flycatcher',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/041.Scissor_tailed_Flycatcher',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/042.Vermilion_Flycatcher',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/043.Yellow_bellied_Flycatcher',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/044.Frigatebird',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/045.Northern_Fulmar',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/046.Gadwall',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/047.American_Goldfinch',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/048.European_Goldfinch',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/049.Boat_tailed_Grackle',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/050.Eared_Grebe',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/051.Horned_Grebe',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/052.Pied_billed_Grebe',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/053.Western_Grebe',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/054.Blue_Grosbeak',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/055.Evening_Grosbeak',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/056.Pine_Grosbeak',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/057.Rose_breasted_Grosbeak',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/058.Pigeon_Guillemot',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/059.California_Gull',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/060.Glaucous_winged_Gull',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/061.Heermann_Gull',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/062.Herring_Gull',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/063.Ivory_Gull',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/064.Ring_billed_Gull',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/065.Slaty_backed_Gull',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/066.Western_Gull',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/067.Anna_Hummingbird',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/068.Ruby_throated_Hummingbird',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/069.Rufous_Hummingbird',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/070.Green_Violetear',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/071.Long_tailed_Jaeger',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/072.Pomarine_Jaeger',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/073.Blue_Jay',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/074.Florida_Jay',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/075.Green_Jay',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/076.Dark_eyed_Junco',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/077.Tropical_Kingbird',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/078.Gray_Kingbird',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/079.Belted_Kingfisher',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/080.Green_Kingfisher',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/081.Pied_Kingfisher',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/082.Ringed_Kingfisher',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/083.White_breasted_Kingfisher',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/084.Red_legged_Kittiwake',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/085.Horned_Lark',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/086.Pacific_Loon',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/087.Mallard',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/088.Western_Meadowlark',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/089.Hooded_Merganser',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/090.Red_breasted_Merganser',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/091.Mockingbird',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/092.Nighthawk',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/093.Clark_Nutcracker',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/094.White_breasted_Nuthatch',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/095.Baltimore_Oriole',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/096.Hooded_Oriole',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/097.Orchard_Oriole',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/098.Scott_Oriole',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/099.Ovenbird',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/100.Brown_Pelican',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/101.White_Pelican',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/102.Western_Wood_Pewee',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/103.Sayornis',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/104.American_Pipit',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/105.Whip_poor_Will',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/106.Horned_Puffin',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/107.Common_Raven',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/108.White_necked_Raven',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/109.American_Redstart',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/110.Geococcyx',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/111.Loggerhead_Shrike',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/112.Great_Grey_Shrike',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/113.Baird_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/114.Black_throated_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/115.Brewer_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/116.Chipping_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/117.Clay_colored_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/118.House_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/119.Field_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/120.Fox_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/121.Grasshopper_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/122.Harris_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/123.Henslow_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/124.Le_Conte_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/125.Lincoln_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/126.Nelson_Sharp_tailed_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/127.Savannah_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/128.Seaside_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/129.Song_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/130.Tree_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/131.Vesper_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/132.White_crowned_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/133.White_throated_Sparrow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/134.Cape_Glossy_Starling',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/135.Bank_Swallow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/136.Barn_Swallow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/137.Cliff_Swallow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/138.Tree_Swallow',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/139.Scarlet_Tanager',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/140.Summer_Tanager',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/141.Artic_Tern',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/142.Black_Tern',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/143.Caspian_Tern',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/144.Common_Tern',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/145.Elegant_Tern',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/146.Forsters_Tern',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/147.Least_Tern',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/148.Green_tailed_Towhee',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/149.Brown_Thrasher',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/150.Sage_Thrasher',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/151.Black_capped_Vireo',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/152.Blue_headed_Vireo',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/153.Philadelphia_Vireo',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/154.Red_eyed_Vireo',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/155.Warbling_Vireo',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/156.White_eyed_Vireo',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/157.Yellow_throated_Vireo',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/158.Bay_breasted_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/159.Black_and_white_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/160.Black_throated_Blue_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/161.Blue_winged_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/162.Canada_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/163.Cape_May_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/164.Cerulean_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/165.Chestnut_sided_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/166.Golden_winged_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/167.Hooded_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/168.Kentucky_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/169.Magnolia_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/170.Mourning_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/171.Myrtle_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/172.Nashville_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/173.Orange_crowned_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/174.Palm_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/175.Pine_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/176.Prairie_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/177.Prothonotary_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/178.Swainson_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/179.Tennessee_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/180.Wilson_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/181.Worm_eating_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/182.Yellow_Warbler',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/183.Northern_Waterthrush',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/184.Louisiana_Waterthrush',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/185.Bohemian_Waxwing',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/186.Cedar_Waxwing',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/187.American_Three_toed_Woodpecker',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/188.Pileated_Woodpecker',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/189.Red_bellied_Woodpecker',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/190.Red_cockaded_Woodpecker',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/191.Red_headed_Woodpecker',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/192.Downy_Woodpecker',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/193.Bewick_Wren',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/194.Cactus_Wren',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/195.Carolina_Wren',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/196.House_Wren',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/197.Marsh_Wren',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/198.Rock_Wren',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/199.Winter_Wren',
#  '/content/drive/MyDrive/IT수업/데이터/CUB200/train/200.Common_Yellowthroat']

# %%
def convertXYData(foldername):
  x_train,y_train = [],[]
  for i, class_name in  enumerate(os.listdir(foldername)):        
    if i < no_class:      
      for fname in os.listdir(foldername+'/'+class_name):        
        img = image.load_img(foldername+'/'+class_name+'/'+fname,target_size=(224,224) )        
        if len(img.getbands()) != 3:
          print(f"유효하지 않은 영상발생 {class_name} {fname}")
          continue
        x = image.img_to_array(img)
        x = preprocess_input(x)
        x_train.append(x)
        y_train.append(i)
  return (x_train,y_train)

# %%
x_train,y_train = convertXYData(train_folder)

# %%
x_test,y_test = convertXYData(test_folder)

# %%
np.array(x_train).shape, np.array(x_test).shape
# Out:
# ((600, 224, 224, 3), (515, 224, 224, 3))

# %%
np.array(y_train).shape, np.array(y_test).shape
# Out:
# ((600,), (515,))

# %%
x_train = np.asarray(x_train)
y_train = np.asarray(y_train)
x_test =  np.asarray(x_test)
y_test = np.asarray(y_test)

# %%
y_train = tf.keras.utils.to_categorical(y_train,no_class)
y_test = tf.keras.utils.to_categorical(y_test,no_class)

# %%
# help(ResNet50)
base_model = ResNet50(weights='imagenet',input_shape=(224, 224, 3), include_top = False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# 94781440/94765736 [==============================] - 0s 0us/step

# %%
cnn = Sequential()
cnn.add(base_model)
###################  메인 알고리즘 설계 끝

# %%
# 분류를 하기위해서 FC
cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))
cnn.add(Dense(no_class,activation='softmax'))

# %%
from tensorflow.python import metrics
cnn.compile(loss=tf.keras.losses.categorical_crossentropy,optimizer=Adam(0.00002),metrics=['accuracy'])
hist = cnn.fit(x_train,y_train,batch_size=16,epochs=10,validation_data=(x_test,y_test),verbose=1)
# Out:
# Epoch 1/10
# 38/38 [==============================] - 28s 294ms/step - loss: 2.7014 - accuracy: 0.3567 - val_loss: 1.1276 - val_accuracy: 0.6757
# Epoch 2/10
# 38/38 [==============================] - 9s 229ms/step - loss: 0.0303 - accuracy: 0.9900 - val_loss: 1.2661 - val_accuracy: 0.6427
# Epoch 3/10
# 38/38 [==============================] - 10s 255ms/step - loss: 0.0070 - accuracy: 0.9983 - val_loss: 1.1143 - val_accuracy: 0.6757
# Epoch 4/10
# 38/38 [==============================] - 9s 231ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.1135 - val_accuracy: 0.6660
# Epoch 5/10
# 38/38 [==============================] - 9s 232ms/step - loss: 6.7048e-04 - accuracy: 1.0000 - val_loss: 1.1067 - val_accuracy: 0.6583
# Epoch 6/10
# 38/38 [==============================] - 9s 233ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.1083 - val_accuracy: 0.6563
# Epoch 7/10
# 38/38 [==============================] - 9s 234ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.2377 - val_accuracy: 0.6330
# Epoch 8/10
# 38/38 [==============================] - 10s 260ms/step - loss: 8.6849e-04 - accuracy: 1.0000 - val_loss: 1.2082 - val_accuracy: 0.6388
# Epoch 9/10
# 38/38 [==============================] - 9s 237ms/step - loss: 4.7033e-04 - accuracy: 1.0000 - val_loss: 1.2040 - val_accuracy: 0.6369
# Epoch 10/10
# 38/38 [==============================] - 9s 238ms/step - loss: 2.8563e-04 - accuracy: 1.0000 - val_loss: 1.1870 - val_accuracy: 0.6369

# %%
res = cnn.evaluate(x_test,y_test,verbose=0)
res
# Out:
# [1.1870296001434326, 0.6368932127952576]

# %%
# 미세조정 방식과 동결방식
# 미세조정방식 fine-tuning
# 컨볼루션층과 완전연결층의 가중치를 동시에 수정
# 학습률을 낮게 유지하여 조금씩 수정

# 동결방식
# 컨볼루션층의 가중치를 동결하여 수정이 일어나지 않게 제한함
# base_model.trainable = false

# 미세조정방식이 조금 더 우세하다는 결론

# %%
# 물체 검출
# 분류 : classification, 검출 : detection, 분할 : segmentation 문제
# R-CNN
# Fast R-CNN
# Faster R-CNN
# YOLO >> 가장 진보된 검출 알고리즘

# %%
import numpy as np
import cv2 # 컴퓨터 비전 라이브러리

# %%
classes = []

# %%
# 욜로 MS COCO 데이터 셋에 대해 학습
with open("/content/drive/MyDrive/IT수업/데이터/YOLO/coco.names.txt",'r') as f:
  classes = [line.strip() for line in f.readlines()]

# %%
colors = np.random.uniform(0,255,size=(len(classes),3))
colors
# Out:
# array([[186.68506395, 129.70050607, 152.88461703],
#        [242.75343529, 210.36521056,  61.63679167],
#        [166.65851794, 234.13031597,   7.81776737],
#        [205.06653485, 131.65230242, 186.19892552],
#        [209.23370074, 230.94112667, 237.14383768],
#        [119.17646319,  25.63562521, 107.74282141],
#        [  9.27048616, 222.81120041, 243.3081217 ],
#        [ 63.60012185,  25.6418237 , 151.50867489],
#        [122.25326531,  60.96133481,  77.48281797],
#        [195.80834296, 232.39721361,  39.96636153],
#        [ 43.4967925 , 119.36120245, 216.29832213],
#        [ 38.17858347, 159.66705245, 133.92428167],
#        [153.25360733,  18.78380837,  38.85967435],
#        [226.06503546, 204.35289647, 135.69389068],
#        [177.5240669 ,  92.57255291, 109.36152432],
#        [221.59236518, 124.17478217,  27.44084633],
#        [254.00124767,  60.64088066,  53.99541224],
#        [240.32052303,  29.85379481,  17.70807183],
#        [ 47.73664143,  80.68078422, 204.26719401],
#        [ 61.51622735, 177.90582661,  43.96878128],
#        [145.96365478, 104.07832064, 140.21913693],
#        [105.89286909,  22.31252978, 233.84277413],
#        [200.41574385, 246.76708702,  87.21807905],
#        [ 41.92682627, 163.20382648, 204.11745305],
#        [ 46.56010725, 137.79613983,  35.4527503 ],
#        [ 53.53188504,  96.7381215 , 232.03588626],
#        [236.48368712,  38.38071625,  56.25839574],
#        [ 61.2139264 ,  41.68348042,  18.33889439],
#        [228.48039891, 234.09249521, 124.75544022],
#        [222.09289021, 219.57686471, 126.16883455],
#        [109.24630267, 167.76330631,  79.53467847],
#        [192.21787626,  51.36812944, 100.03782765],
#        [ 21.66963081, 252.13579902, 245.1395534 ],
#        [ 27.26188349,  64.25937275,  23.69386516],
#        [118.13226381,  54.52139062,  27.15703128],
#        [241.59212977, 133.63389407,  88.62041127],
#        [117.80161948,   2.2354762 ,  61.33213089],
#        [  7.40894362,  64.44834896, 214.18112735],
#        [202.92711227, 235.97254693, 246.38355875],
#        [113.41844013,  84.43830952, 160.17196377],
#        [  9.54370663, 222.84932742, 225.87690499],
#        [254.66889495, 244.05192118, 143.66957341],
#        [130.34388646, 235.38197623,  15.05803973],
#        [ 34.80837446, 101.42975052,   3.05340506],
#        [186.16533788,  64.33698596, 254.32460776],
#        [120.79525197, 165.74406809, 200.96136782],
#        [211.82817295,  42.36801901, 125.93734496],
#        [198.12911434, 224.05176574, 193.74792209],
#        [  9.62479606, 134.55219947, 149.80954143],
#        [140.05777073,  76.39996291,  56.34284259],
#        [135.01093342, 188.36700723, 238.51793998],
#        [100.63574335,   2.42316755,  70.84830992],
#        [107.54147376, 151.07020303, 212.94974003],
#        [  2.01123213, 242.79028048, 127.74175641],
#        [ 29.38418021,  94.44297477, 105.1461383 ],
#        [169.5641525 ,  25.20210499,  26.01561666],
#        [142.45768618, 106.25345325, 164.997727  ],
#        [210.76786148,  38.69766794,  89.87384433],
#        [ 94.87307678, 104.82329197,  55.48356361],
#        [ 94.40895131, 239.74924012,  49.2046794 ],
#        [206.39540163, 205.16227847,  26.86333796],
#        [ 97.77026189,  25.92713995,  10.28676164],
#        [173.41294176, 135.7974694 , 181.31255145],
#        [252.79879389, 121.20174979, 116.66190354],
#        [  4.79034801,  91.8831003 , 115.31075533],
#        [252.73423244, 176.27657751, 233.3636162 ],
#        [ 24.67885272, 252.10983028, 101.44409455],
#        [199.01149843,  55.38046502, 162.4732215 ],
#        [  2.85295076, 172.41894486, 100.5786815 ],
#        [  4.98140451, 155.2724078 , 231.65535838],
#        [161.07451434,  89.54216326,  41.79064888],
#        [147.52283533, 190.73565569,  19.76055679],
#        [232.71227639, 179.57204079, 245.02904177],
#        [153.51789026, 170.45915062, 214.55509976],
#        [207.83104597, 170.22165848, 198.19125874],
#        [251.15713759, 158.22517336,  43.30423383],
#        [ 53.49615605,  74.46877253, 111.85115518],
#        [133.32228043,  90.84222297, 243.62111286],
#        [ 51.25583464, 247.91471722, 143.75387429],
#        [ 35.77832654,  98.9949205 , 121.78182697]])

# %%
# 테스트 할 영상을 읽는다.
img = cv2.imread('/content/drive/MyDrive/IT수업/데이터/YOLO/yolo_test.jpg')
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
height, width, channels = img.shape
height, width, channels
# Out:
# (576, 768, 3)

# %%
blob = cv2.dnn.blobFromImage(img,1.0/256,(448,448),(0,0,0), swapRB = True, crop = False)
yolo_model = cv2.dnn.readNet('/content/drive/MyDrive/IT수업/데이터/YOLO/yolov3.weights','/content/drive/MyDrive/IT수업/데이터/YOLO/yolov3.cfg')
layer_names = yolo_model.getLayerNames()

# %%
layer_names
# Out:
# ('conv_0',
#  'bn_0',
#  'leaky_1',
#  'conv_1',
#  'bn_1',
#  'leaky_2',
#  'conv_2',
#  'bn_2',
#  'leaky_3',
#  'conv_3',
#  'bn_3',
#  'leaky_4',
#  'shortcut_4',
#  'conv_5',
#  'bn_5',
#  'leaky_6',
#  'conv_6',
#  'bn_6',
#  'leaky_7',
#  'conv_7',
#  'bn_7',
#  'leaky_8',
#  'shortcut_8',
#  'conv_9',
#  'bn_9',
#  'leaky_10',
#  'conv_10',
#  'bn_10',
#  'leaky_11',
#  'shortcut_11',
#  'conv_12',
#  'bn_12',
#  'leaky_13',
#  'conv_13',
#  'bn_13',
#  'leaky_14',
#  'conv_14',
#  'bn_14',
#  'leaky_15',
#  'shortcut_15',
#  'conv_16',
#  'bn_16',
#  'leaky_17',
#  'conv_17',
#  'bn_17',
#  'leaky_18',
#  'shortcut_18',
#  'conv_19',
#  'bn_19',
#  'leaky_20',
#  'conv_20',
#  'bn_20',
#  'leaky_21',
#  'shortcut_21',
#  'conv_22',
#  'bn_22',
#  'leaky_23',
#  'conv_23',
#  'bn_23',
#  'leaky_24',
#  'shortcut_24',
#  'conv_25',
#  'bn_25',
#  'leaky_26',
#  'conv_26',
#  'bn_26',
#  'leaky_27',
#  'shortcut_27',
#  'conv_28',
#  'bn_28',
#  'leaky_29',
#  'conv_29',
#  'bn_29',
#  'leaky_30',
#  'shortcut_30',
#  'conv_31',
#  'bn_31',
#  'leaky_32',
#  'conv_32',
#  'bn_32',
#  'leaky_33',
#  'shortcut_33',
#  'conv_34',
#  'bn_34',
#  'leaky_35',
#  'conv_35',
#  'bn_35',
#  'leaky_36',
#  'shortcut_36',
#  'conv_37',
#  'bn_37',
#  'leaky_38',
#  'conv_38',
#  'bn_38',
#  'leaky_39',
#  'conv_39',
#  'bn_39',
#  'leaky_40',
#  'shortcut_40',
#  'conv_41',
#  'bn_41',
#  'leaky_42',
#  'conv_42',
#  'bn_42',
#  'leaky_43',
#  'shortcut_43',
#  'conv_44',
#  'bn_44',
#  'leaky_45',
#  'conv_45',
#  'bn_45',
#  'leaky_46',
#  'shortcut_46',
#  'conv_47',
#  'bn_47',
#  'leaky_48',
#  'conv_48',
#  'bn_48',
#  'leaky_49',
#  'shortcut_49',
#  'conv_50',
#  'bn_50',
#  'leaky_51',
#  'conv_51',
#  'bn_51',
#  'leaky_52',
#  'shortcut_52',
#  'conv_53',
#  'bn_53',
#  'leaky_54',
#  'conv_54',
#  'bn_54',
#  'leaky_55',
#  'shortcut_55',
#  'conv_56',
#  'bn_56',
#  'leaky_57',
#  'conv_57',
#  'bn_57',
#  'leaky_58',
#  'shortcut_58',
#  'conv_59',
#  'bn_59',
#  'leaky_60',
#  'conv_60',
#  'bn_60',
#  'leaky_61',
#  'shortcut_61',
#  'conv_62',
#  'bn_62',
#  'leaky_63',
#  'conv_63',
#  'bn_63',
#  'leaky_64',
#  'conv_64',
#  'bn_64',
#  'leaky_65',
#  'shortcut_65',
#  'conv_66',
#  'bn_66',
#  'leaky_67',
#  'conv_67',
#  'bn_67',
#  'leaky_68',
#  'shortcut_68',
#  'conv_69',
#  'bn_69',
#  'leaky_70',
#  'conv_70',
#  'bn_70',
#  'leaky_71',
#  'shortcut_71',
#  'conv_72',
#  'bn_72',
#  'leaky_73',
#  'conv_73',
#  'bn_73',
#  'leaky_74',
#  'shortcut_74',
#  'conv_75',
#  'bn_75',
#  'leaky_76',
#  'conv_76',
#  'bn_76',
#  'leaky_77',
#  'conv_77',
#  'bn_77',
#  'leaky_78',
#  'conv_78',
#  'bn_78',
#  'leaky_79',
#  'conv_79',
#  'bn_79',
#  'leaky_80',
#  'conv_80',
#  'bn_80',
#  'leaky_81',
#  'conv_81',
#  'permute_82',
#  'yolo_82',
#  'identity_83',
#  'conv_84',
#  'bn_84',
#  'leaky_85',
#  'upsample_85',
#  'concat_86',
#  'conv_87',
#  'bn_87',
#  'leaky_88',
#  'conv_88',
#  'bn_88',
#  'leaky_89',
#  'conv_89',
#  'bn_89',
#  'leaky_90',
#  'conv_90',
#  'bn_90',
#  'leaky_91',
#  'conv_91',
#  'bn_91',
#  'leaky_92',
#  'conv_92',
#  'bn_92',
#  'leaky_93',
#  'conv_93',
#  'permute_94',
#  'yolo_94',
#  'identity_95',
#  'conv_96',
#  'bn_96',
#  'leaky_97',
#  'upsample_97',
#  'concat_98',
#  'conv_99',
#  'bn_99',
#  'leaky_100',
#  'conv_100',
#  'bn_100',
#  'leaky_101',
#  'conv_101',
#  'bn_101',
#  'leaky_102',
#  'conv_102',
#  'bn_102',
#  'leaky_103',
#  'conv_103',
#  'bn_103',
#  'leaky_104',
#  'conv_104',
#  'bn_104',
#  'leaky_105',
#  'conv_105',
#  'permute_106',
#  'yolo_106')

# %%
out_layers = [layer_names[i-1] for i in yolo_model.getUnconnectedOutLayers()]
out_layers
# Out:
# ['yolo_82', 'yolo_94', 'yolo_106']

# %%
# 테스트 영상을 신경망에 입력
yolo_model.setInput(blob)
outputData =  yolo_model.forward(out_layers)

# %%
class_ids,confidences,boxes=[],[],[]
output3=yolo_model.forward(out_layers)
for output in output3:
    for vec85 in output:
        scores=vec85[5:]
        class_id=np.argmax(scores)
        confidence=scores[class_id]
        if confidence>0.6: # 신뢰도가 50% 이상인 경우만 취함
            centerx,centery=int(vec85[0]*width),int(vec85[1]*height)  # [0,1] 표현을 영상 크기로 변환
            w,h=int(vec85[2]*width),int(vec85[3]*height)
            x,y=int(centerx-w/2),int(centery-h/2)
            boxes.append([x,y,w,h])
            confidences.append(float(confidence))
            class_ids.append(class_id)
        
indexes=cv2.dnn.NMSBoxes(boxes,confidences,0.5,0.4)
for i in range(len(boxes)):
    if i in indexes:
        x,y,w,h=boxes[i]
        text=str(classes[class_ids[i]])+'%.3f'%confidences[i]
        cv2.rectangle(img,(x,y),(x+w,y+h),colors[class_ids[i]],2)
        cv2.putText(img,text,(x,y+30),cv2.FONT_HERSHEY_PLAIN,2,colors[class_ids[i]],2)
        
from google.colab.patches import cv2_imshow    
cv2_imshow(img)    

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=768x576 at 0x7F427215C550>
