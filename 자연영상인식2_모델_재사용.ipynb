# %%
# 학습된 모델 불러서 다시 사용
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import cifar10

# %%
# 신경망 구조와 가중치를 저장하고 있는 파일을 읽어옴

# %%
cnn = tf.keras.models.load_model("/content/cnn1.h5")
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 10, 10, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 5, 5, 64)          0
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 512)               819712
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 890,410
# Trainable params: 890,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
(x_train, y_train),(x_test,y_test) = cifar10.load_data()
x_train = x_train.astype(np.float32)/255.0
x_test = x_test.astype(np.float32)/255.0

y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# %%
# 정확률 평가
res = cnn.evaluate(x_test,y_test,verbose=2)
res
# Out:
# 313/313 - 10s - loss: 0.6339 - accuracy: 0.7909 - 10s/epoch - 33ms/step
# [0.6339213252067566, 0.7908999919891357]

# %%
from tensorflow.python.framework.ops import name_scope_v1
cnn.layers[0].name
# Out:
# 'conv2d'

# %%
for layer in cnn.layers:
  if 'conv' in layer.name:
    kernel,biases = layer.get_weights()
    print(layer.name, kernel.shape)
# Out:
# conv2d (3, 3, 3, 32)
# conv2d_1 (3, 3, 32, 32)
# conv2d_2 (3, 3, 32, 64)
# conv2d_3 (3, 3, 64, 64)

# %%
# 맨 앞에 있는 컨볼루션층의 커널 정보를 추출
kernel, biases = cnn.layers[0].get_weights()

# %%
minv, maxv = kernel.min(), kernel.max()

# %%
# 커널의 값을 표준화 minmax scaler
kernel = (kernel - minv) / (maxv - minv)
kernel
# Out:
# array([[[[0.4133796 , 0.22622469, 0.64668506, 0.5491728 , 0.440317  ,
#           0.20669366, 0.5139584 , 0.44289494, 0.5044104 , 0.32196355,
#           0.56609654, 0.14908502, 0.790096  , 0.34800756, 0.4180863 ,
#           0.30966067, 0.54746276, 0.46432886, 0.580656  , 0.44549194,
#           0.5971025 , 0.25287193, 0.6939845 , 0.45637983, 0.1987125 ,
#           0.41531444, 0.26982257, 0.3894992 , 0.583986  , 0.39159253,
#           0.50718075, 0.4094065 ],
#          [0.25405872, 0.4371914 , 0.62886524, 0.3846247 , 0.60491765,
#           0.19118027, 0.36693546, 0.31832013, 0.35210833, 0.54605925,
#           0.5176173 , 0.3867654 , 0.427633  , 0.22445975, 0.38576767,
#           0.41932368, 0.60369647, 0.30945906, 0.44894335, 0.3338459 ,
#           0.30770922, 0.24369581, 0.22841361, 0.4172957 , 0.3020699 ,
#           0.36491424, 0.24833986, 0.66073465, 0.4039122 , 0.3049995 ,
#           0.20174736, 0.32830378],
#          [0.48296836, 0.12085446, 0.33625796, 0.5453311 , 0.6146763 ,
#           0.47257465, 0.66055435, 0.6643111 , 0.44645202, 0.5893169 ,
#           0.519808  , 0.58786064, 0.5130075 , 0.48193645, 0.27011782,
#           0.2639805 , 0.4019078 , 0.5412601 , 0.7536584 , 0.52043897,
#           0.38085657, 0.15156277, 0.26135772, 0.21535566, 0.61280423,
#           0.14520387, 0.46890825, 0.62198645, 0.59398544, 0.61291146,
#           0.29100505, 0.2776526 ]],
#
#         [[0.6155828 , 0.57854265, 0.59558535, 0.75577116, 0.22483963,
#           0.42860818, 0.40283686, 0.578915  , 0.5030334 , 0.57668734,
#           0.44410244, 0.5406268 , 0.32028842, 0.4788421 , 0.14877808,
#           0.5331892 , 0.5478563 , 0.4403855 , 0.39826906, 0.38563606,
#           0.66514015, 0.28790805, 0.7436646 , 0.50913876, 0.60497266,
#           0.4207162 , 0.4651328 , 0.5755907 , 0.7475898 , 0.4242328 ,
#           0.6153362 , 0.4844593 ],
#          [0.45672163, 0.65346104, 0.48837107, 0.5728992 , 0.3113492 ,
#           0.37382427, 0.5047762 , 0.4585978 , 0.41384998, 0.33715716,
#           0.77976614, 0.577717  , 0.37344977, 0.25871605, 0.46125007,
#           0.35814625, 0.6296772 , 0.4597978 , 0.5469507 , 0.6580076 ,
#           0.55553216, 0.2177714 , 0.28083172, 0.50744176, 0.6067492 ,
#           0.30701306, 0.49819148, 0.5099755 , 0.5602406 , 0.48029512,
#           0.26520932, 0.6011362 ],
#          [0.59757084, 0.29188874, 0.35332638, 0.36407468, 0.18068022,
#           0.57207143, 0.43359303, 0.5790317 , 0.28827712, 0.6703131 ,
#           0.43101534, 0.50741637, 0.28296608, 0.1432893 , 0.15814024,
#           0.56046665, 0.49213195, 0.42886767, 0.5608343 , 0.45752707,
#           0.5973106 , 0.3758029 , 0.3563475 , 0.47048232, 0.35626295,
#           0.32300273, 0.45763904, 0.40026897, 0.71728504, 0.26724815,
#           0.21629389, 0.27449396]],
#
#         [[0.49652523, 0.6767057 , 0.40709415, 0.8049951 , 0.38398588,
#           0.51953137, 0.38558224, 0.4627853 , 0.42110875, 0.4924217 ,
#           0.401067  , 0.3576038 , 0.30962196, 0.4093978 , 0.6219111 ,
#           0.41756546, 0.27443162, 0.70132446, 0.52795047, 0.3336806 ,
#           0.36079356, 0.26686084, 0.5633597 , 0.7840914 , 0.4314885 ,
#           0.19922687, 0.8299332 , 0.47971213, 0.3782144 , 0.33939135,
#           0.58913344, 0.29022652],
#          [0.45505452, 0.6383275 , 0.3582628 , 0.5681354 , 0.41945615,
#           0.61208016, 0.5251769 , 0.29078156, 0.3085421 , 0.32610413,
#           0.76991224, 0.66586506, 0.26429605, 0.23140138, 0.66895056,
#           0.4625324 , 0.48435065, 0.52627736, 0.55514795, 0.6090214 ,
#           0.2556286 , 0.43179098, 0.4920408 , 0.39618108, 0.54227614,
#           0.        , 0.7135013 , 0.4072124 , 0.47970918, 0.3721702 ,
#           0.5843301 , 0.40219596],
#          [0.5614179 , 0.47481865, 0.22788261, 0.5263594 , 0.60602736,
#           0.49472815, 0.40456688, 0.52634037, 0.1807218 , 0.6056197 ,
#           0.44458234, 0.7017484 , 0.32323745, 0.3392037 , 0.6681649 ,
#           0.3532824 , 0.5402763 , 0.7182541 , 0.67112917, 0.3802765 ,
#           0.755954  , 0.14246191, 0.42102405, 0.53844565, 0.62831616,
#           0.07654621, 0.5472885 , 0.27799702, 0.28743884, 0.45381367,
#           0.3960864 , 0.49605313]]],
#
#
#        [[[0.47731477, 0.32785362, 0.55386317, 0.6250422 , 0.302381  ,
#           0.40139335, 0.52425617, 0.5564104 , 0.43824723, 0.655547  ,
#           0.24787106, 0.18799916, 0.48383534, 0.501013  , 0.77667433,
#           0.2709747 , 0.29185688, 0.56143695, 0.23888515, 0.3878632 ,
#           0.6703864 , 0.42182606, 0.7359099 , 0.68117607, 0.6911381 ,
#           0.501319  , 0.20479521, 0.27245438, 0.30898708, 0.7908174 ,
#           0.46339092, 0.53280425],
#          [0.3627632 , 0.14665452, 0.77517444, 0.2975547 , 0.51157314,
#           0.44865972, 0.26091427, 0.36089242, 0.28843877, 0.2704787 ,
#           0.6446239 , 0.5554827 , 0.38745776, 0.4763999 , 0.7035981 ,
#           0.5086239 , 0.641569  , 0.6195206 , 0.40348774, 0.40593955,
#           0.33456758, 0.53035945, 0.27230316, 0.62874967, 0.5806689 ,
#           0.3572859 , 0.30007938, 0.476773  , 0.51190287, 0.8067435 ,
#           0.39619943, 0.54672915],
#          [0.34435102, 0.4083187 , 0.45855978, 0.6274455 , 0.30574268,
#           0.28733507, 0.29671267, 0.4910459 , 0.32630712, 0.5415128 ,
#           0.30964467, 0.24333028, 0.4355086 , 0.4190615 , 0.83689827,
#           0.5749357 , 0.36736026, 0.42206615, 0.63343537, 0.29441622,
#           0.44179887, 0.34057876, 0.34551394, 0.5576743 , 0.56106627,
#           0.16129392, 0.19439454, 0.7225772 , 0.46474773, 0.4829527 ,
#           0.25817436, 0.43630585]],
#
#         [[0.76638883, 0.5946745 , 0.6214641 , 0.44056275, 0.60874015,
#           0.48360232, 0.40751755, 0.6588054 , 0.6881881 , 0.5471622 ,
#           0.2527634 , 0.53905654, 0.75029916, 0.31256846, 0.27602905,
#           0.6082642 , 0.7008376 , 0.34413782, 0.34750703, 0.48014864,
#           0.69829875, 0.68351346, 0.76160365, 0.39937532, 0.54939115,
#           0.36296874, 0.38955203, 0.5214106 , 0.54600674, 0.65411085,
#           0.53155136, 0.6470332 ],
#          [0.6624847 , 0.5562518 , 0.7191232 , 0.38257805, 0.54457206,
#           0.40865144, 0.3420498 , 0.33845392, 0.8457001 , 0.6066242 ,
#           0.5195749 , 0.59887815, 0.6969873 , 0.4591908 , 0.46166387,
#           0.36150688, 0.72547525, 0.5743183 , 0.6735061 , 0.53294736,
#           0.391104  , 0.3863637 , 0.33247444, 0.2623152 , 0.55112636,
#           0.17492265, 0.34665856, 0.3502374 , 0.3638497 , 0.42760175,
#           0.60943997, 0.36924118],
#          [0.82673186, 0.60036665, 0.58929974, 0.3127014 , 0.29068744,
#           0.3572952 , 0.42995307, 0.56135744, 0.621838  , 0.37173232,
#           0.25461277, 0.31300408, 0.73306835, 0.6595931 , 0.55944735,
#           0.3585757 , 0.740157  , 0.7079933 , 0.6715276 , 0.68568057,
#           0.75667745, 0.6400062 , 0.42838022, 0.65272236, 0.6093742 ,
#           0.35343295, 0.26557216, 0.7215139 , 0.5580864 , 0.55706817,
#           0.63076174, 0.3997486 ]],
#
#         [[0.47428754, 0.28479397, 0.454645  , 0.33706674, 0.72929543,
#           0.57732105, 0.7662985 , 0.48346993, 0.34934345, 0.32777533,
#           0.5625251 , 0.39803064, 0.5901991 , 0.30040234, 0.4062246 ,
#           0.2696042 , 0.23937863, 0.42758885, 0.37931517, 0.41851264,
#           0.22078255, 0.4926256 , 0.4364522 , 0.3880927 , 0.52526593,
#           0.18523325, 0.69765073, 0.5598243 , 0.09787519, 0.5010607 ,
#           0.4922338 , 0.5498444 ],
#          [0.24756458, 0.43742603, 0.47962457, 0.60556835, 0.684495  ,
#           0.53673947, 0.735574  , 0.41014877, 0.6490667 , 0.4088238 ,
#           0.67028606, 0.34070846, 0.2597809 , 0.5256335 , 0.33752823,
#           0.43005055, 0.1447175 , 0.49003264, 0.44905424, 0.41595325,
#           0.21716195, 0.23739009, 0.21649362, 0.6274577 , 0.46810597,
#           0.08843995, 0.37567058, 0.46441203, 0.09065247, 0.27387953,
#           0.46076927, 0.4700732 ],
#          [0.62935597, 0.5540504 , 0.31092498, 0.32086653, 0.59641117,
#           0.670548  , 0.6557488 , 0.17491865, 0.4521736 , 0.66397727,
#           0.27666086, 0.3946647 , 0.5609728 , 0.6873693 , 0.37428263,
#           0.58866835, 0.36446953, 0.5319553 , 0.34759822, 0.55682653,
#           0.43523312, 0.22652383, 0.42580247, 0.5663451 , 0.6229944 ,
#           0.30744344, 0.33292383, 0.35787302, 0.08824742, 0.2732616 ,
#           0.51324373, 0.3438677 ]]],
#
#
#        [[[0.45624772, 0.60213614, 0.16874948, 0.34178218, 0.48443443,
#           0.61699545, 0.27412054, 0.6093267 , 0.24034853, 0.40740985,
#           0.3876357 , 0.5778417 , 0.47169653, 0.71048963, 0.4588249 ,
#           0.47203952, 0.38868958, 0.30512112, 0.33240423, 0.3288756 ,
#           0.51906204, 0.6188972 , 0.5088967 , 0.67004025, 0.51302433,
#           0.18337533, 0.6422876 , 0.43022516, 0.49295157, 0.66863817,
#           0.23433857, 0.3716995 ],
#          [0.09704034, 0.6567631 , 0.38400295, 0.53285474, 0.61101633,
#           0.32514673, 0.19458961, 0.2979778 , 0.17744073, 0.5257563 ,
#           0.42408788, 0.67157555, 0.27998474, 0.46708623, 0.26028544,
#           0.5150579 , 0.5662077 , 0.29690233, 0.26192534, 0.51970375,
#           0.14514774, 0.6820859 , 0.2982024 , 0.6731197 , 0.27509785,
#           0.3999549 , 0.3861188 , 0.53270334, 0.668424  , 0.6077473 ,
#           0.5656724 , 0.5548942 ],
#          [0.19696625, 0.5934106 , 0.36961886, 0.58806026, 0.39329588,
#           0.3744112 , 0.234011  , 0.26532277, 0.23451898, 0.68420285,
#           0.58394384, 0.48955342, 0.543728  , 0.63618124, 0.2802517 ,
#           0.47194308, 0.28070557, 0.49583146, 0.4472375 , 0.6522407 ,
#           0.2971431 , 0.41159856, 0.33102113, 0.69126666, 0.44383308,
#           0.22717601, 0.48545194, 0.47398454, 0.43631667, 0.47581708,
#           0.68243843, 0.21663246]],
#
#         [[0.6156223 , 0.3672475 , 0.5230706 , 0.2904207 , 0.5742211 ,
#           0.6553679 , 0.4829634 , 0.60752845, 0.84506476, 0.24765266,
#           0.59115875, 0.52570856, 0.2654692 , 0.71634245, 0.45735848,
#           0.35844722, 0.33384567, 0.1305833 , 0.3719344 , 0.32676035,
#           0.65034217, 0.59993565, 0.66745204, 0.01282093, 0.30172884,
#           0.4805098 , 0.48254398, 0.2131013 , 0.3848575 , 0.4589506 ,
#           0.388514  , 0.25811607],
#          [0.51123387, 0.5425354 , 0.26239735, 0.21163814, 0.2661636 ,
#           0.4261004 , 0.63907903, 0.42683578, 0.8641298 , 0.34995908,
#           0.6257343 , 0.6551832 , 0.36847562, 0.559898  , 0.32771626,
#           0.4035735 , 0.70728153, 0.18711725, 0.35453677, 0.46317837,
#           0.5034872 , 0.7079962 , 0.28776827, 0.1061883 , 0.16583462,
#           0.09852178, 0.6174423 , 0.4107815 , 0.3870874 , 0.49737525,
#           0.2728233 , 0.4500143 ],
#          [0.635588  , 0.6272019 , 0.30348328, 0.5906813 , 0.5022703 ,
#           0.5203286 , 0.47361404, 0.5949853 , 1.        , 0.39569476,
#           0.3125055 , 0.29151383, 0.7041407 , 0.63906777, 0.5612154 ,
#           0.5075599 , 0.5908803 , 0.59320074, 0.37211168, 0.7501615 ,
#           0.37861267, 0.54756045, 0.58184344, 0.2399239 , 0.2945004 ,
#           0.29248708, 0.46864617, 0.59559685, 0.5148098 , 0.5312861 ,
#           0.5892014 , 0.36796468]],
#
#         [[0.3384082 , 0.4095648 , 0.4526997 , 0.34999084, 0.29538044,
#           0.67581356, 0.70367104, 0.7146291 , 0.14097674, 0.69609314,
#           0.21189788, 0.536123  , 0.3964646 , 0.5478873 , 0.68804437,
#           0.30838713, 0.3512509 , 0.36538187, 0.29644212, 0.21204793,
#           0.38906777, 0.29235783, 0.49906394, 0.35200727, 0.6881941 ,
#           0.2562409 , 0.34511265, 0.32493463, 0.75328046, 0.373208  ,
#           0.526492  , 0.38883942],
#          [0.29501572, 0.36455357, 0.36383164, 0.25055557, 0.40096292,
#           0.54753417, 0.4508142 , 0.49105906, 0.45923194, 0.50245696,
#           0.27647898, 0.6552613 , 0.4458857 , 0.44401008, 0.52675164,
#           0.5400369 , 0.207046  , 0.41287658, 0.3980291 , 0.35979304,
#           0.3441883 , 0.2574087 , 0.39291748, 0.5127554 , 0.3640502 ,
#           0.3413487 , 0.34614202, 0.43534738, 0.6434942 , 0.24485983,
#           0.5117161 , 0.40210164],
#          [0.51650006, 0.36690122, 0.67503333, 0.4120219 , 0.49102253,
#           0.5081196 , 0.5033955 , 0.21646403, 0.5594296 , 0.5511021 ,
#           0.43248022, 0.3810924 , 0.58856785, 0.44142887, 0.5765208 ,
#           0.2951743 , 0.4311273 , 0.6207435 , 0.5423109 , 0.695755  ,
#           0.45623836, 0.34802392, 0.6156527 , 0.28157094, 0.2778904 ,
#           0.52053887, 0.26126465, 0.2289419 , 0.5575155 , 0.3665028 ,
#           0.3444399 , 0.42910323]]]], dtype=float32)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
kernel.shape
# Out:
# (3, 3, 3, 32)

# %%
temp = kernel[:,:,:,0]
temp = temp[:,:,0]
plt.imshow(temp,cmap = 'gray')

# %%
from tensorflow.python.ops.gen_array_ops import rank_eager_fallback
# (3,3,3,32)

plt.figure(figsize=(20,3))
for i in range(32):
  f = kernel[:,:,:,i]
  for j in range(3):
    plt.subplot(3,32,j*32+i+1)
    temp = f[:,:,j]
    plt.imshow(temp,cmap = 'gray')

# %%
# 신경망의 특징 맵을 시각화
for layer in cnn.layers:
  if 'conv' in layer.name:
    print(layer.name, layer.output.shape)
# Out:
# conv2d (None, 30, 30, 32)
# conv2d_1 (None, 28, 28, 32)
# conv2d_2 (None, 12, 12, 64)
# conv2d_3 (None, 10, 10, 64)

# %%
# 0번째 층을 따로 떼어내서 객체에 저장
from tensorflow.keras.models import Model

# %%
m =  Model(inputs = cnn.inputs, outputs=cnn.layers[0].output)
m.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_input (InputLayer)   [(None, 32, 32, 3)]       0
#
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
# =================================================================
# Total params: 896
# Trainable params: 896
# Non-trainable params: 0
# _________________________________________________________________

# %%
feature_map = m.predict(x_test)

# %%
fm = feature_map[0]
plt.imshow(x_test[0])

# %%
plt.imshow(fm[:,:,0])

# %%
plt.figure(figsize = (23,3))
for i in range(32):
  plt.subplot(2,16,i+1)
  plt.imshow(fm[:,:,i],cmap='gray')
  plt.xticks([]) # x축 삭제
  plt.yticks([]) # y축 삭제

# %%
# 딥러닝의 전략
# 충분히 큰 신경망 구조를 사용하되 다양한 규제 기법을 적용하여 과잉 적합을 방지
# 데이터 증대, 드랍아웃, 가중치 감쇠, 앙상블, 배치 정규화등의 다양한 규제 기법이 있음
from IPython import display
display.Image("/content/033.JPG")

# %%
# 데이터를 늘리는 행위는 비용증가
# 딥러닝에서는 주어진 데이터를 인위적으로 늘리는 데이터 증대(data augmentation)를 적용
# 영상을 이동, 회전, 또는 좌우반전
# 명암 조정등
# 텐서플로에서 제공하는 라이브러리를 이용

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
xx_train, yy_train = x_train[:12], y_train[:12]

# %%
xx_train.shape, yy_train.shape
# Out:
# ((12, 32, 32, 3), (12, 10))

# %%
plt.figure(figsize=(16,2))
for i in range(12):
  plt.subplot(1,12,i+1)
  plt.imshow(xx_train[i])
  plt.xticks([])
  plt.yticks([])

# %%
generator = ImageDataGenerator(rotation_range=30.0, width_shift_range=0.2, height_shift_range=0.2, horizontal_flip=True)

# %%
gen = generator.flow(xx_train,yy_train, batch_size = 6)

# %%
cls_name = ['plane','car','bird','cat','deer','dog','frog','horse','ship','truck']
img, label = gen.next() # 함수를 호출할 때 마다 batch_size 매개변수가 지정한 수 만큼 영상 생성
plt.figure(figsize=(16,3))
for i in range(6):
  plt.subplot(1,6,i+1)
  plt.imshow(img[i])
  plt.xticks([])
  plt.yticks([])
  plt.title(cls_name[np.argmax(label[i])])

# %%
# 증대된 영상으로 신경망 학습

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.python.ops.math_ops import Max
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 데이터 로드
(x_train, y_train),(x_test,y_test) = cifar10.load_data()
x_train = x_train.astype(np.float32)/255.0
x_test = x_test.astype(np.float32)/255.0

y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# %%
# 신경망 설계 ccp d f(flatten) fc d fc
cnn = Sequential()
cnn.add(Conv2D(32,(3,3), activation='relu', input_shape = (32,32,3)))
cnn.add(Conv2D(32,(3,3), activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Dropout(0.25))

cnn.add(Conv2D(64,(3,3), activation='relu'))
cnn.add(Conv2D(64,(3,3), activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Dropout(0.25))

cnn.add(Flatten())
cnn.add(Dense(512, activation = 'relu'))
cnn.add(Dropout(0.5))
cnn.add(Dense(10,activation='softmax'))

# %%
cnn.compile(loss = tf.keras.losses.categorical_crossentropy, optimizer=Adam(),metrics=['accuracy'])
batch_size = 128
generator = ImageDataGenerator(rotation_range=30.0,width_shift_range=0.2,height_shift_range=0.2,horizontal_flip=True)
hist = cnn.fit_generator(generator.flow(x_train,y_train,batch_size=batch_size),epochs=10,validation_data=(x_test,y_test),verbose=2)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   after removing the cwd from sys.path.
# 391/391 - 22s - loss: 1.8537 - accuracy: 0.3070 - val_loss: 1.4620 - val_accuracy: 0.4697 - 22s/epoch - 57ms/step
# Epoch 2/10
# 391/391 - 20s - loss: 1.5698 - accuracy: 0.4222 - val_loss: 1.3977 - val_accuracy: 0.5100 - 20s/epoch - 52ms/step
# Epoch 3/10
# 391/391 - 21s - loss: 1.4358 - accuracy: 0.4783 - val_loss: 1.1943 - val_accuracy: 0.5701 - 21s/epoch - 54ms/step
# Epoch 4/10
# 391/391 - 20s - loss: 1.3544 - accuracy: 0.5120 - val_loss: 1.3042 - val_accuracy: 0.5466 - 20s/epoch - 52ms/step
# Epoch 5/10
# 391/391 - 21s - loss: 1.3013 - accuracy: 0.5353 - val_loss: 1.1018 - val_accuracy: 0.6059 - 21s/epoch - 53ms/step
# Epoch 6/10
# 391/391 - 21s - loss: 1.2468 - accuracy: 0.5551 - val_loss: 1.1181 - val_accuracy: 0.6011 - 21s/epoch - 53ms/step
# Epoch 7/10
# 391/391 - 20s - loss: 1.2168 - accuracy: 0.5666 - val_loss: 1.0952 - val_accuracy: 0.6074 - 20s/epoch - 52ms/step
# Epoch 8/10
# 391/391 - 21s - loss: 1.1835 - accuracy: 0.5779 - val_loss: 1.0583 - val_accuracy: 0.6285 - 21s/epoch - 53ms/step
# Epoch 9/10
# 391/391 - 21s - loss: 1.1566 - accuracy: 0.5898 - val_loss: 1.0041 - val_accuracy: 0.6446 - 21s/epoch - 52ms/step
# Epoch 10/10
# 391/391 - 20s - loss: 1.1390 - accuracy: 0.5952 - val_loss: 0.9976 - val_accuracy: 0.6417 - 20s/epoch - 52ms/step

# %% [markdown]
# # Day 11

# %%
#신경망 모델 정확률 평가
res = cnn.evaluate(x_test,y_test,verbose=0)
res
# 이전에 했던 데이터를 증대시키지 않았던 모델에 비해 성능이 향상된 것을 확인
# Out:
# [0.9975972771644592, 0.641700029373169]

# %%
# 정확률 , 손실함수 그래프 
# -- 이전 코드 참조

# %%
# 드랍아웃 - 규제 기법
# 일정비율의 가중치를 불능으로 만들고 학습 , 
# 불능이되는 에지는 샘플마다 독립적으로 정하는데. 난수를 이용해서 랜덤하게 선택
from IPython import display
display.Image('/content/034.JPG')

# %%
# 드랍아웃  
# 드랍아웃의 성능 향상을 측정하는 프로그램
# 교차검증을 적용해서 실험결과의 신뢰성을 높임

# %%
# 라이브러리 로드
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import KFold

# %%
#데이터 로드
(x_train,y_train),(x_test,y_test)= cifar10.load_data()
x_train = x_train.astype(np.float32)/255.0
x_test = x_test.astype(np.float32)/255.0
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# %%
#하이퍼 매개변수  설정
batch_size = 128
n_epoch = 10
k=2 #

# %%
from re import VERBOSE
from tensorflow.python.ops.batch_ops import batch
from pyparsing import actions
# 드랍아웃의 비율에 따라 교차검증을 수행하고 정확율을 반환하는 함수
def cross_validation(dropout_rate:list):
  accuracy = [] 
  for train_index, val_index in  KFold(k).split(x_train):
    #훈련과 검증으로 분할
    xtrain, xval =  x_train[train_index], x_train[val_index]
    ytrain, yval =  y_train[train_index], y_train[val_index]
    #신경망 모델 설계
    cnn = Sequential()
    cnn.add(Conv2D(32,(3,3),activation='relu', input_shape = (32,32,3)))
    cnn.add(Conv2D(32,(3,3),activation='relu'))
    cnn.add(MaxPooling2D(pool_size=(2,2)))
    cnn.add(Dropout(dropout_rate[0]))
    
    cnn.add(Conv2D(64,(3,3),activation='relu'))
    cnn.add(Conv2D(64,(3,3),activation='relu'))
    cnn.add(MaxPooling2D(pool_size=(2,2)))
    cnn.add(Dropout(dropout_rate[1]))

    cnn.add(Flatten())

    cnn.add(Dense(512,activation = 'relu'))
    cnn.add(Dropout(dropout_rate[2]))
    cnn.add(Dense(10,activation = 'softmax'))

    # 신경망 모델을 학습하고 평가
    cnn.compile(loss = tf.keras.losses.categorical_crossentropy,optimizer = Adam(), metrics = ['accuracy'])
    cnn.fit(xtrain,ytrain,batch_size=batch_size,epochs=n_epoch,verbose=0)
    accuracy.append( cnn.evaluate(xval,yval,verbose=0)[1])
  return accuracy

# %%
cnn_widthout_drop = cross_validation([0.0,0.0,0.0])
cnn_width_drop = cross_validation([0.25,0.25,0.5])

# %%
np.mean( cnn_widthout_drop), np.mean( cnn_width_drop)
# Out:
# (0.6823599934577942, 0.7141799926757812)

# %%
import seaborn as sns
sns.boxplot(data=[cnn_widthout_drop,cnn_width_drop])

# %%
# 과잉적합에서는 가중치 값이 아주큰 현상
# 가중치 감소.. 이것은 성능을 유지한 채로 가중치를 크게 낮추는 규제
# 세가지 매개변수
# 가중치, Kernel_regularize
# 바이어스,  Bias regularize
# 활성함수 결과에 적용 Activity_regularizer
# from tensorflow.keras import regularizers
# cnn.add(Dense(64,kernel_regularizer=regularizers.l2(0.01), activity_regularizer=regularizers.l1(0.01)))
# L1 규제 : L1규제는 손실 함수에 가중치의 절대값인 L1 노름(norm)을 추가 한다
# L2 규제는 손실 함수에 가중치에 대한 L2 노름(norm)의 제곱을 더한다.

# %%
# 성능평가
# 하이퍼매개변수를 최적화 나 모델선택이 중요
# 객관적인 평가
# 1. 교차검증
# 2. 제거 조사 ablation study
#   선택사항이 여러개 있을때 선택사항을 하나씩 빼고 성능을 측정해서 선택사항의 각각의 기여도를 평가

# %%
# 3가지 옵션에 대해서 제거조사.. 교차검증으로 제거 조사에 대한 결과에  신뢰성을 높임

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import KFold
from tensorflow.keras import regularizers

# %%
# CIFAR-10데이터셋을 읽고 신경망에 입력할 형태로 변환
(x_train,y_train),(x_test,y_test) =  cifar10.load_data()
x_train = x_train.astype(np.float16)/255.0
x_test = x_test.astype(np.float16)/255.0
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000, 10), (10000, 10))

# %%
#하이퍼매개변수
batch_size=128
n_epoch = 10
k = 5

# %%
# 하이퍼 매개변수에 따라서 교차검증을 수행하고 정확률을 반환하는 함수
def cross_validation(data_gen,dropout_rate,l2_reg):
  accuracy = [] 
  for train_index, val_index in  KFold(k).split(x_train):
    #훈련과 검증으로 분할
    xtrain, xval =  x_train[train_index], x_train[val_index]
    ytrain, yval =  y_train[train_index], y_train[val_index]
    #신경망 모델 설계
    cnn = Sequential()
    cnn.add(Conv2D(32,(3,3),activation='relu', input_shape = (32,32,3)))
    cnn.add(Conv2D(32,(3,3),activation='relu'))
    cnn.add(MaxPooling2D(pool_size=(2,2)))
    cnn.add(Dropout(dropout_rate[0]))
    
    cnn.add(Conv2D(64,(3,3),activation='relu'))
    cnn.add(Conv2D(64,(3,3),activation='relu'))
    cnn.add(MaxPooling2D(pool_size=(2,2)))
    cnn.add(Dropout(dropout_rate[1]))

    cnn.add(Flatten())

    cnn.add(Dense(512,activation = 'relu'))
    cnn.add(Dropout(dropout_rate[2]))
    cnn.add(Dense(10,activation = 'softmax',kernel_regularizer=regularizers.l2(l2_reg)) )

    # 신경망 모델을 학습하고 평가
    cnn.compile(loss = tf.keras.losses.categorical_crossentropy,optimizer = Adam(), metrics = ['accuracy'])
    if data_gen:
      generator = ImageDataGenerator()
      cnn.fit_generator(generator.flow(x_train,y_train,batch_size = batch_size)
        ,epochs=n_epoch,validation_data=(x_test,y_test), verbose=2 )
    else:
      cnn.fit(xtrain,ytrain,batch_size=batch_size,epochs=n_epoch,validation_data=(x_test,y_test), verbose=2 )
      
    accuracy.append( cnn.evaluate(xval,yval,verbose=0)[1])
  return accuracy

# %%
# 오래걸림...
cnn_000 = cross_validation(False,[0.0,0.0,0.0],0.0)
cnn_001 = cross_validation(False,[0.0,0.0,0.0],0.01)
cnn_010 = cross_validation(False,[0.25,0.25,0.5],0.0)
cnn_011 = cross_validation(False,[0.25,0.25,0.5],0.01)
cnn_100 = cross_validation(True,[0.0,0.0,0.0],0.0)
cnn_101 = cross_validation(True,[0.0,0.0,0.0],0.01)
cnn_110 = cross_validation(True,[0.25,0.25,0.5],0.0)
cnn_111 = cross_validation(True,[0.25,0.25,0.5],0.01)
# Out:
# Epoch 1/10
# 313/313 - 4s - loss: 1.5709 - accuracy: 0.4325 - val_loss: 1.2988 - val_accuracy: 0.5389 - 4s/epoch - 14ms/step
# Epoch 2/10
# 313/313 - 3s - loss: 1.1727 - accuracy: 0.5822 - val_loss: 1.1112 - val_accuracy: 0.6025 - 3s/epoch - 9ms/step
# Epoch 3/10
# 313/313 - 3s - loss: 0.9597 - accuracy: 0.6646 - val_loss: 0.9268 - val_accuracy: 0.6781 - 3s/epoch - 9ms/step
# Epoch 4/10
# 313/313 - 3s - loss: 0.8182 - accuracy: 0.7145 - val_loss: 0.8594 - val_accuracy: 0.7017 - 3s/epoch - 10ms/step
# Epoch 5/10
# 313/313 - 3s - loss: 0.6960 - accuracy: 0.7581 - val_loss: 0.8332 - val_accuracy: 0.7114 - 3s/epoch - 9ms/step
# Epoch 6/10
# 313/313 - 3s - loss: 0.6026 - accuracy: 0.7867 - val_loss: 0.7686 - val_accuracy: 0.7351 - 3s/epoch - 9ms/step
# Epoch 7/10
# 313/313 - 3s - loss: 0.5009 - accuracy: 0.8246 - val_loss: 0.8243 - val_accuracy: 0.7281 - 3s/epoch - 10ms/step
# Epoch 8/10
# 313/313 - 3s - loss: 0.4081 - accuracy: 0.8584 - val_loss: 0.8406 - val_accuracy: 0.7320 - 3s/epoch - 10ms/step
# Epoch 9/10
# 313/313 - 3s - loss: 0.3338 - accuracy: 0.8828 - val_loss: 0.8418 - val_accuracy: 0.7388 - 3s/epoch - 9ms/step
# Epoch 10/10
# 313/313 - 3s - loss: 0.2550 - accuracy: 0.9110 - val_loss: 0.9464 - val_accuracy: 0.7291 - 3s/epoch - 9ms/step
# Epoch 1/10
# 313/313 - 5s - loss: 1.5937 - accuracy: 0.4166 - val_loss: 1.3079 - val_accuracy: 0.5272 - 5s/epoch - 14ms/step
# Epoch 2/10
# 313/313 - 3s - loss: 1.1844 - accuracy: 0.5785 - val_loss: 1.0888 - val_accuracy: 0.6148 - 3s/epoch - 9ms/step
# Epoch 3/10
# 313/313 - 3s - loss: 0.9827 - accuracy: 0.6552 - val_loss: 0.9703 - val_accuracy: 0.6558 - 3s/epoch - 10ms/step
# Epoch 4/10
# 313/313 - 3s - loss: 0.8523 - accuracy: 0.7015 - val_loss: 0.9013 - val_accuracy: 0.6846 - 3s/epoch - 9ms/step
# Epoch 5/10
# 313/313 - 3s - loss: 0.7327 - accuracy: 0.7438 - val_loss: 0.8799 - val_accuracy: 0.7012 - 3s/epoch - 9ms/step
# Epoch 6/10
# 313/313 - 3s - loss: 0.6379 - accuracy: 0.7781 - val_loss: 0.8392 - val_accuracy: 0.7159 - 3s/epoch - 9ms/step
# Epoch 7/10
# 313/313 - 3s - loss: 0.5439 - accuracy: 0.8102 - val_loss: 0.8146 - val_accuracy: 0.7269 - 3s/epoch - 10ms/step
# Epoch 8/10
# 313/313 - 3s - loss: 0.4518 - accuracy: 0.8429 - val_loss: 0.9522 - val_accuracy: 0.7053 - 3s/epoch - 9ms/step
# Epoch 9/10
# 313/313 - 3s - loss: 0.3569 - accuracy: 0.8773 - val_loss: 0.9379 - val_accuracy: 0.7177 - 3s/epoch - 10ms/step
# Epoch 10/10
# 313/313 - 3s - loss: 0.2854 - accuracy: 0.9012 - val_loss: 1.0120 - val_accuracy: 0.7268 - 3s/epoch - 9ms/step
# Epoch 1/10
# 313/313 - 4s - loss: 1.5752 - accuracy: 0.4277 - val_loss: 1.3808 - val_accuracy: 0.5018 - 4s/epoch - 12ms/step
# Epoch 2/10
# 313/313 - 3s - loss: 1.1846 - accuracy: 0.5785 - val_loss: 1.0946 - val_accuracy: 0.6155 - 3s/epoch - 10ms/step
# Epoch 3/10
# 313/313 - 3s - loss: 0.9816 - accuracy: 0.6538 - val_loss: 0.9521 - val_accuracy: 0.6628 - 3s/epoch - 10ms/step
# Epoch 4/10
# 313/313 - 3s - loss: 0.8398 - accuracy: 0.7058 - val_loss: 0.8734 - val_accuracy: 0.6973 - 3s/epoch - 10ms/step
# Epoch 5/10
# 313/313 - 3s - loss: 0.7262 - accuracy: 0.7470 - val_loss: 0.8576 - val_accuracy: 0.7021 - 3s/epoch - 10ms/step
# Epoch 6/10
# 313/313 - 3s - loss: 0.6205 - accuracy: 0.7857 - val_loss: 0.8492 - val_accuracy: 0.7142 - 3s/epoch - 10ms/step
# Epoch 7/10
# 313/313 - 3s - loss: 0.5190 - accuracy: 0.8198 - val_loss: 0.8457 - val_accuracy: 0.7241 - 3s/epoch - 9ms/step
# Epoch 8/10
# 313/313 - 3s - loss: 0.4288 - accuracy: 0.8505 - val_loss: 0.8567 - val_accuracy: 0.7273 - 3s/epoch - 9ms/step
# Epoch 9/10
# 313/313 - 3s - loss: 0.3377 - accuracy: 0.8817 - val_loss: 0.8893 - val_accuracy: 0.7278 - 3s/epoch - 10ms/step
# Epoch 10/10
# 313/313 - 3s - loss: 0.2449 - accuracy: 0.9168 - val_loss: 1.0541 - val_accuracy: 0.7137 - 3s/epoch - 9ms/step
# Epoch 1/10
# 313/313 - 4s - loss: 1.5727 - accuracy: 0.4282 - val_loss: 1.2698 - val_accuracy: 0.5380 - 4s/epoch - 13ms/step
# Epoch 2/10
# 313/313 - 3s - loss: 1.1561 - accuracy: 0.5908 - val_loss: 1.0903 - val_accuracy: 0.6132 - 3s/epoch - 10ms/step
# Epoch 3/10
# 313/313 - 3s - loss: 0.9507 - accuracy: 0.6646 - val_loss: 0.9261 - val_accuracy: 0.6803 - 3s/epoch - 10ms/step
# Epoch 4/10
# 313/313 - 3s - loss: 0.8003 - accuracy: 0.7185 - val_loss: 0.8793 - val_accuracy: 0.6924 - 3s/epoch - 9ms/step
# Epoch 5/10
# 313/313 - 3s - loss: 0.6838 - accuracy: 0.7628 - val_loss: 0.7900 - val_accuracy: 0.7282 - 3s/epoch - 10ms/step
# Epoch 6/10
# 313/313 - 3s - loss: 0.5798 - accuracy: 0.7980 - val_loss: 0.8032 - val_accuracy: 0.7316 - 3s/epoch - 10ms/step
# Epoch 7/10
# 313/313 - 3s - loss: 0.4756 - accuracy: 0.8361 - val_loss: 0.8008 - val_accuracy: 0.7401 - 3s/epoch - 9ms/step
# Epoch 8/10
# 313/313 - 3s - loss: 0.3880 - accuracy: 0.8654 - val_loss: 0.8515 - val_accuracy: 0.7320 - 3s/epoch - 9ms/step
# Epoch 9/10
# 313/313 - 3s - loss: 0.2999 - accuracy: 0.8960 - val_loss: 0.9868 - val_accuracy: 0.7174 - 3s/epoch - 10ms/step
# Epoch 10/10
# 313/313 - 3s - loss: 0.2253 - accuracy: 0.9207 - val_loss: 1.0185 - val_accuracy: 0.7343 - 3s/epoch - 9ms/step
# Epoch 1/10
# 313/313 - 4s - loss: 1.5954 - accuracy: 0.4208 - val_loss: 1.3420 - val_accuracy: 0.5097 - 4s/epoch - 12ms/step
# Epoch 2/10
# 313/313 - 3s - loss: 1.1999 - accuracy: 0.5712 - val_loss: 1.1311 - val_accuracy: 0.6007 - 3s/epoch - 10ms/step
# Epoch 3/10
# 313/313 - 3s - loss: 0.9844 - accuracy: 0.6540 - val_loss: 0.9893 - val_accuracy: 0.6518 - 3s/epoch - 9ms/step
# Epoch 4/10
# 313/313 - 3s - loss: 0.8392 - accuracy: 0.7069 - val_loss: 0.8714 - val_accuracy: 0.6941 - 3s/epoch - 10ms/step
# Epoch 5/10
# 313/313 - 3s - loss: 0.7038 - accuracy: 0.7541 - val_loss: 0.8380 - val_accuracy: 0.7159 - 3s/epoch - 10ms/step
# Epoch 6/10
# 313/313 - 3s - loss: 0.5980 - accuracy: 0.7928 - val_loss: 0.8197 - val_accuracy: 0.7189 - 3s/epoch - 10ms/step
# Epoch 7/10
# 313/313 - 3s - loss: 0.4965 - accuracy: 0.8266 - val_loss: 0.8465 - val_accuracy: 0.7265 - 3s/epoch - 10ms/step
# Epoch 8/10
# 313/313 - 3s - loss: 0.3997 - accuracy: 0.8612 - val_loss: 0.8678 - val_accuracy: 0.7229 - 3s/epoch - 9ms/step
# Epoch 9/10
# 313/313 - 3s - loss: 0.3002 - accuracy: 0.8954 - val_loss: 0.9521 - val_accuracy: 0.7283 - 3s/epoch - 10ms/step
# Epoch 10/10
# 313/313 - 3s - loss: 0.2171 - accuracy: 0.9258 - val_loss: 1.0924 - val_accuracy: 0.7185 - 3s/epoch - 10ms/step
# Epoch 1/10
# 313/313 - 4s - loss: 1.6833 - accuracy: 0.4063 - val_loss: 1.3532 - val_accuracy: 0.5236 - 4s/epoch - 13ms/step
# Epoch 2/10
# 313/313 - 3s - loss: 1.2697 - accuracy: 0.5604 - val_loss: 1.1519 - val_accuracy: 0.6049 - 3s/epoch - 10ms/step
# Epoch 3/10
# 313/313 - 3s - loss: 1.0609 - accuracy: 0.6370 - val_loss: 1.0069 - val_accuracy: 0.6551 - 3s/epoch - 10ms/step
# Epoch 4/10
# 313/313 - 3s - loss: 0.9162 - accuracy: 0.6919 - val_loss: 0.9480 - val_accuracy: 0.6808 - 3s/epoch - 10ms/step
# Epoch 5/10
# 313/313 - 3s - loss: 0.7994 - accuracy: 0.7330 - val_loss: 0.8782 - val_accuracy: 0.7083 - 3s/epoch - 10ms/step
# Epoch 6/10
# 313/313 - 3s - loss: 0.7064 - accuracy: 0.7661 - val_loss: 0.8541 - val_accuracy: 0.7181 - 3s/epoch - 10ms/step
# Epoch 7/10
# 313/313 - 3s - loss: 0.6174 - accuracy: 0.7990 - val_loss: 0.8092 - val_accuracy: 0.7350 - 3s/epoch - 10ms/step
# Epoch 8/10
# 313/313 - 3s - loss: 0.5427 - accuracy: 0.8267 - val_loss: 0.8283 - val_accuracy: 0.7392 - 3s/epoch - 10ms/step
# Epoch 9/10
# 313/313 - 3s - loss: 0.4669 - accuracy: 0.8532 - val_loss: 0.8703 - val_accuracy: 0.7346 - 3s/epoch - 10ms/step
# Epoch 10/10
# 313/313 - 3s - loss: 0.3934 - accuracy: 0.8798 - val_loss: 0.9428 - val_accuracy: 0.7281 - 3s/epoch - 10ms/step
# Epoch 1/10
# 313/313 - 4s - loss: 1.6654 - accuracy: 0.4155 - val_loss: 1.3740 - val_accuracy: 0.5239 - 4s/epoch - 12ms/step
# Epoch 2/10
# 313/313 - 3s - loss: 1.2702 - accuracy: 0.5605 - val_loss: 1.1679 - val_accuracy: 0.6008 - 3s/epoch - 9ms/step
# Epoch 3/10
# 313/313 - 3s - loss: 1.0781 - accuracy: 0.6351 - val_loss: 1.0313 - val_accuracy: 0.6455 - 3s/epoch - 9ms/step
# Epoch 4/10
# 313/313 - 3s - loss: 0.9379 - accuracy: 0.6829 - val_loss: 1.0263 - val_accuracy: 0.6429 - 3s/epoch - 10ms/step
# Epoch 5/10
# 313/313 - 3s - loss: 0.8302 - accuracy: 0.7211 - val_loss: 0.9084 - val_accuracy: 0.6920 - 3s/epoch - 10ms/step
# Epoch 6/10
# 313/313 - 3s - loss: 0.7399 - accuracy: 0.7559 - val_loss: 0.8671 - val_accuracy: 0.7069 - 3s/epoch - 9ms/step
# Epoch 7/10
# 313/313 - 3s - loss: 0.6586 - accuracy: 0.7848 - val_loss: 0.8834 - val_accuracy: 0.7082 - 3s/epoch - 10ms/step
# Epoch 8/10
# 313/313 - 3s - loss: 0.5832 - accuracy: 0.8105 - val_loss: 0.8342 - val_accuracy: 0.7335 - 3s/epoch - 9ms/step
# Epoch 9/10
# 313/313 - 3s - loss: 0.5157 - accuracy: 0.8338 - val_loss: 0.8699 - val_accuracy: 0.7258 - 3s/epoch - 10ms/step
# Epoch 10/10
# 313/313 - 3s - loss: 0.4518 - accuracy: 0.8573 - val_loss: 0.8779 - val_accuracy: 0.7298 - 3s/epoch - 9ms/step
# Epoch 1/10
# 313/313 - 4s - loss: 1.6695 - accuracy: 0.4159 - val_loss: 1.5384 - val_accuracy: 0.4847 - 4s/epoch - 13ms/step
# Epoch 2/10
# 313/313 - 3s - loss: 1.2640 - accuracy: 0.5651 - val_loss: 1.1617 - val_accuracy: 0.6015 - 3s/epoch - 11ms/step
# Epoch 3/10
# 313/313 - 3s - loss: 1.0749 - accuracy: 0.6342 - val_loss: 1.0295 - val_accuracy: 0.6519 - 3s/epoch - 10ms/step
# Epoch 4/10
# 313/313 - 3s - loss: 0.9308 - accuracy: 0.6860 - val_loss: 0.9204 - val_accuracy: 0.6926 - 3s/epoch - 9ms/step
# Epoch 5/10
# 313/313 - 3s - loss: 0.8232 - accuracy: 0.7250 - val_loss: 0.8902 - val_accuracy: 0.7020 - 3s/epoch - 10ms/step
# Epoch 6/10
# 313/313 - 3s - loss: 0.7289 - accuracy: 0.7578 - val_loss: 0.8134 - val_accuracy: 0.7297 - 3s/epoch - 10ms/step
# Epoch 7/10
# 313/313 - 3s - loss: 0.6414 - accuracy: 0.7894 - val_loss: 0.8202 - val_accuracy: 0.7362 - 3s/epoch - 10ms/step
# Epoch 8/10
# 313/313 - 3s - loss: 0.5786 - accuracy: 0.8125 - val_loss: 0.8290 - val_accuracy: 0.7331 - 3s/epoch - 10ms/step
# Epoch 9/10
# 313/313 - 3s - loss: 0.5106 - accuracy: 0.8359 - val_loss: 0.8328 - val_accuracy: 0.7391 - 3s/epoch - 10ms/step
# Epoch 10/10
# 313/313 - 3s - loss: 0.4432 - accuracy: 0.8596 - val_loss: 0.9166 - val_accuracy: 0.7270 - 3s/epoch - 10ms/step
# Epoch 1/10
# 313/313 - 4s - loss: 1.6859 - accuracy: 0.4101 - val_loss: 1.4419 - val_accuracy: 0.4912 - 4s/epoch - 13ms/step
# Epoch 2/10
# 313/313 - 3s - loss: 1.3037 - accuracy: 0.5450 - val_loss: 1.2489 - val_accuracy: 0.5662 - 3s/epoch - 10ms/step
# Epoch 3/10
# 313/313 - 3s - loss: 1.1117 - accuracy: 0.6190 - val_loss: 1.1339 - val_accuracy: 0.6032 - 3s/epoch - 10ms/step
# Epoch 4/10
# 313/313 - 3s - loss: 0.9833 - accuracy: 0.6684 - val_loss: 1.0304 - val_accuracy: 0.6506 - 3s/epoch - 10ms/step
# Epoch 5/10
# 313/313 - 3s - loss: 0.8697 - accuracy: 0.7070 - val_loss: 0.9355 - val_accuracy: 0.6854 - 3s/epoch - 9ms/step
# Epoch 6/10
# 313/313 - 3s - loss: 0.7834 - accuracy: 0.7384 - val_loss: 0.9270 - val_accuracy: 0.6939 - 3s/epoch - 10ms/step
# Epoch 7/10
# 313/313 - 3s - loss: 0.7046 - accuracy: 0.7667 - val_loss: 0.9111 - val_accuracy: 0.7036 - 3s/epoch - 10ms/step
# Epoch 8/10
# 313/313 - 3s - loss: 0.6253 - accuracy: 0.7973 - val_loss: 0.9127 - val_accuracy: 0.7070 - 3s/epoch - 10ms/step
# Epoch 9/10
# 313/313 - 3s - loss: 0.5475 - accuracy: 0.8229 - val_loss: 0.9094 - val_accuracy: 0.7167 - 3s/epoch - 10ms/step
# Epoch 10/10
# 313/313 - 3s - loss: 0.4798 - accuracy: 0.8479 - val_loss: 0.9348 - val_accuracy: 0.7176 - 3s/epoch - 10ms/step
# Epoch 1/10
# 313/313 - 4s - loss: 1.6741 - accuracy: 0.4112 - val_loss: 1.4093 - val_accuracy: 0.5136 - 4s/epoch - 13ms/step
# Epoch 2/10
# 313/313 - 3s - loss: 1.2514 - accuracy: 0.5681 - val_loss: 1.1565 - val_accuracy: 0.5989 - 3s/epoch - 10ms/step
# Epoch 3/10
# 313/313 - 3s - loss: 1.0669 - accuracy: 0.6360 - val_loss: 1.0793 - val_accuracy: 0.6296 - 3s/epoch - 10ms/step
# Epoch 4/10
# 313/313 - 3s - loss: 0.9361 - accuracy: 0.6838 - val_loss: 0.9733 - val_accuracy: 0.6676 - 3s/epoch - 9ms/step
# Epoch 5/10
# 313/313 - 3s - loss: 0.8392 - accuracy: 0.7178 - val_loss: 0.9097 - val_accuracy: 0.6968 - 3s/epoch - 10ms/step
# Epoch 6/10
# 313/313 - 3s - loss: 0.7572 - accuracy: 0.7483 - val_loss: 0.8776 - val_accuracy: 0.7069 - 3s/epoch - 10ms/step
# Epoch 7/10
# 313/313 - 3s - loss: 0.6655 - accuracy: 0.7819 - val_loss: 0.8325 - val_accuracy: 0.7282 - 3s/epoch - 10ms/step
# Epoch 8/10
# 313/313 - 3s - loss: 0.5881 - accuracy: 0.8100 - val_loss: 0.8589 - val_accuracy: 0.7261 - 3s/epoch - 10ms/step
# Epoch 9/10
# 313/313 - 3s - loss: 0.5107 - accuracy: 0.8361 - val_loss: 0.8526 - val_accuracy: 0.7368 - 3s/epoch - 10ms/step
# Epoch 10/10
# 313/313 - 3s - loss: 0.4372 - accuracy: 0.8639 - val_loss: 0.8880 - val_accuracy: 0.7335 - 3s/epoch - 10ms/step
# Epoch 1/10
# 313/313 - 5s - loss: 1.7280 - accuracy: 0.3587 - val_loss: 1.3786 - val_accuracy: 0.4925 - 5s/epoch - 17ms/step
# Epoch 2/10
# 313/313 - 3s - loss: 1.3476 - accuracy: 0.5131 - val_loss: 1.1430 - val_accuracy: 0.5947 - 3s/epoch - 11ms/step
# Epoch 3/10
# 313/313 - 3s - loss: 1.1602 - accuracy: 0.5875 - val_loss: 1.0299 - val_accuracy: 0.6394 - 3s/epoch - 10ms/step
# Epoch 4/10
# 313/313 - 3s - loss: 1.0468 - accuracy: 0.6293 - val_loss: 0.9603 - val_accuracy: 0.6650 - 3s/epoch - 11ms/step
# Epoch 5/10
# 313/313 - 3s - loss: 0.9537 - accuracy: 0.6635 - val_loss: 0.8793 - val_accuracy: 0.6929 - 3s/epoch - 10ms/step
# Epoch 6/10
# 313/313 - 3s - loss: 0.8890 - accuracy: 0.6870 - val_loss: 0.8314 - val_accuracy: 0.7143 - 3s/epoch - 10ms/step
# Epoch 7/10
# 313/313 - 3s - loss: 0.8366 - accuracy: 0.7038 - val_loss: 0.7888 - val_accuracy: 0.7256 - 3s/epoch - 10ms/step
# Epoch 8/10
# 313/313 - 3s - loss: 0.7816 - accuracy: 0.7268 - val_loss: 0.7602 - val_accuracy: 0.7376 - 3s/epoch - 10ms/step
# Epoch 9/10
# 313/313 - 3s - loss: 0.7454 - accuracy: 0.7393 - val_loss: 0.7366 - val_accuracy: 0.7464 - 3s/epoch - 10ms/step
# Epoch 10/10
# 313/313 - 3s - loss: 0.7157 - accuracy: 0.7491 - val_loss: 0.7449 - val_accuracy: 0.7419 - 3s/epoch - 10ms/step
# Epoch 1/10
# 313/313 - 4s - loss: 1.6995 - accuracy: 0.3742 - val_loss: 1.3842 - val_accuracy: 0.5034 - 4s/epoch - 13ms/step
# Epoch 2/10
# 313/313 - 3s - loss: 1.3124 - accuracy: 0.5270 - val_loss: 1.1578 - val_accuracy: 0.5883 - 3s/epoch - 11ms/step
# Epoch 3/10
# 313/313 - 3s - loss: 1.1336 - accuracy: 0.5986 - val_loss: 1.0108 - val_accuracy: 0.6427 - 3s/epoch - 11ms/step
# Epoch 4/10
# 313/313 - 3s - loss: 1.0034 - accuracy: 0.6450 - val_loss: 0.9446 - val_accuracy: 0.6682 - 3s/epoch - 10ms/step
# Epoch 5/10
# 313/313 - 3s - loss: 0.9215 - accuracy: 0.6759 - val_loss: 0.8919 - val_accuracy: 0.6943 - 3s/epoch - 10ms/step
# Epoch 6/10
# 313/313 - 3s - loss: 0.8483 - accuracy: 0.7016 - val_loss: 0.7931 - val_accuracy: 0.7236 - 3s/epoch - 11ms/step
# Epoch 7/10
# 313/313 - 3s - loss: 0.7922 - accuracy: 0.7200 - val_loss: 0.7760 - val_accuracy: 0.7295 - 3s/epoch - 11ms/step
# Epoch 8/10
# 313/313 - 3s - loss: 0.7566 - accuracy: 0.7340 - val_loss: 0.7490 - val_accuracy: 0.7381 - 3s/epoch - 10ms/step
# Epoch 9/10
# 313/313 - 3s - loss: 0.7193 - accuracy: 0.7466 - val_loss: 0.7236 - val_accuracy: 0.7496 - 3s/epoch - 11ms/step
# Epoch 10/10
# 313/313 - 3s - loss: 0.6818 - accuracy: 0.7608 - val_loss: 0.7067 - val_accuracy: 0.7544 - 3s/epoch - 10ms/step
# Epoch 1/10
# 313/313 - 4s - loss: 1.6928 - accuracy: 0.3726 - val_loss: 1.3409 - val_accuracy: 0.5104 - 4s/epoch - 13ms/step
# Epoch 2/10
# 313/313 - 3s - loss: 1.3170 - accuracy: 0.5271 - val_loss: 1.1646 - val_accuracy: 0.5831 - 3s/epoch - 10ms/step
# Epoch 3/10
# 313/313 - 3s - loss: 1.1665 - accuracy: 0.5856 - val_loss: 1.0238 - val_accuracy: 0.6341 - 3s/epoch - 10ms/step
# Epoch 4/10
# 313/313 - 3s - loss: 1.0355 - accuracy: 0.6348 - val_loss: 0.9416 - val_accuracy: 0.6697 - 3s/epoch - 10ms/step
# Epoch 5/10
# 313/313 - 3s - loss: 0.9354 - accuracy: 0.6712 - val_loss: 0.8540 - val_accuracy: 0.6950 - 3s/epoch - 10ms/step
# Epoch 6/10
# 313/313 - 3s - loss: 0.8740 - accuracy: 0.6885 - val_loss: 0.8138 - val_accuracy: 0.7175 - 3s/epoch - 11ms/step
# Epoch 7/10
# 313/313 - 3s - loss: 0.8234 - accuracy: 0.7117 - val_loss: 0.7899 - val_accuracy: 0.7244 - 3s/epoch - 10ms/step
# Epoch 8/10
# 313/313 - 3s - loss: 0.7742 - accuracy: 0.7286 - val_loss: 0.7510 - val_accuracy: 0.7396 - 3s/epoch - 11ms/step
# Epoch 9/10
# 313/313 - 3s - loss: 0.7358 - accuracy: 0.7426 - val_loss: 0.7460 - val_accuracy: 0.7398 - 3s/epoch - 10ms/step
# Epoch 10/10
# 313/313 - 3s - loss: 0.7074 - accuracy: 0.7500 - val_loss: 0.7219 - val_accuracy: 0.7482 - 3s/epoch - 10ms/step
# Epoch 1/10
# 313/313 - 4s - loss: 1.7150 - accuracy: 0.3653 - val_loss: 1.3703 - val_accuracy: 0.5056 - 4s/epoch - 13ms/step
# Epoch 2/10
# 313/313 - 3s - loss: 1.3228 - accuracy: 0.5223 - val_loss: 1.1645 - val_accuracy: 0.5845 - 3s/epoch - 10ms/step
# Epoch 3/10
# 313/313 - 3s - loss: 1.1466 - accuracy: 0.5899 - val_loss: 1.0298 - val_accuracy: 0.6282 - 3s/epoch - 11ms/step
# Epoch 4/10
# 313/313 - 3s - loss: 1.0320 - accuracy: 0.6325 - val_loss: 0.9111 - val_accuracy: 0.6822 - 3s/epoch - 11ms/step
# Epoch 5/10
# 313/313 - 3s - loss: 0.9302 - accuracy: 0.6704 - val_loss: 0.8813 - val_accuracy: 0.6955 - 3s/epoch - 10ms/step
# Epoch 6/10
# 313/313 - 3s - loss: 0.8689 - accuracy: 0.6926 - val_loss: 0.8313 - val_accuracy: 0.7104 - 3s/epoch - 11ms/step
# Epoch 7/10
# 313/313 - 3s - loss: 0.8290 - accuracy: 0.7070 - val_loss: 0.7950 - val_accuracy: 0.7237 - 3s/epoch - 10ms/step
# Epoch 8/10
# 313/313 - 3s - loss: 0.7770 - accuracy: 0.7247 - val_loss: 0.7515 - val_accuracy: 0.7379 - 3s/epoch - 11ms/step
# Epoch 9/10
# 313/313 - 3s - loss: 0.7382 - accuracy: 0.7407 - val_loss: 0.7531 - val_accuracy: 0.7372 - 3s/epoch - 10ms/step
# Epoch 10/10
# 313/313 - 3s - loss: 0.7046 - accuracy: 0.7504 - val_loss: 0.7213 - val_accuracy: 0.7505 - 3s/epoch - 10ms/step
# Epoch 1/10
# 313/313 - 4s - loss: 1.7781 - accuracy: 0.3419 - val_loss: 1.4356 - val_accuracy: 0.4767 - 4s/epoch - 13ms/step
# Epoch 2/10
# 313/313 - 3s - loss: 1.3753 - accuracy: 0.5017 - val_loss: 1.2066 - val_accuracy: 0.5774 - 3s/epoch - 10ms/step
# Epoch 3/10
# 313/313 - 3s - loss: 1.1944 - accuracy: 0.5723 - val_loss: 1.0651 - val_accuracy: 0.6171 - 3s/epoch - 10ms/step
# Epoch 4/10
# 313/313 - 3s - loss: 1.0693 - accuracy: 0.6224 - val_loss: 0.9627 - val_accuracy: 0.6588 - 3s/epoch - 10ms/step
# Epoch 5/10
# 313/313 - 3s - loss: 0.9788 - accuracy: 0.6525 - val_loss: 0.9097 - val_accuracy: 0.6869 - 3s/epoch - 11ms/step
# Epoch 6/10
# 313/313 - 3s - loss: 0.9062 - accuracy: 0.6812 - val_loss: 0.8474 - val_accuracy: 0.7023 - 3s/epoch - 11ms/step
# Epoch 7/10
# 313/313 - 3s - loss: 0.8440 - accuracy: 0.7038 - val_loss: 0.8176 - val_accuracy: 0.7117 - 3s/epoch - 11ms/step
# Epoch 8/10
# 313/313 - 3s - loss: 0.8010 - accuracy: 0.7175 - val_loss: 0.8322 - val_accuracy: 0.7135 - 3s/epoch - 10ms/step
# Epoch 9/10
# 313/313 - 3s - loss: 0.7616 - accuracy: 0.7311 - val_loss: 0.7409 - val_accuracy: 0.7404 - 3s/epoch - 11ms/step
# Epoch 10/10
# 313/313 - 3s - loss: 0.7315 - accuracy: 0.7433 - val_loss: 0.7231 - val_accuracy: 0.7424 - 3s/epoch - 11ms/step
# Epoch 1/10
# 313/313 - 4s - loss: 1.7645 - accuracy: 0.3738 - val_loss: 1.4614 - val_accuracy: 0.4884 - 4s/epoch - 14ms/step
# Epoch 2/10
# 313/313 - 3s - loss: 1.3796 - accuracy: 0.5221 - val_loss: 1.2077 - val_accuracy: 0.5812 - 3s/epoch - 10ms/step
# Epoch 3/10
# 313/313 - 3s - loss: 1.2193 - accuracy: 0.5807 - val_loss: 1.1644 - val_accuracy: 0.5980 - 3s/epoch - 10ms/step
# Epoch 4/10
# 313/313 - 3s - loss: 1.1201 - accuracy: 0.6151 - val_loss: 1.0470 - val_accuracy: 0.6400 - 3s/epoch - 10ms/step
# Epoch 5/10
# 313/313 - 3s - loss: 1.0430 - accuracy: 0.6445 - val_loss: 0.9637 - val_accuracy: 0.6692 - 3s/epoch - 11ms/step
# Epoch 6/10
# 313/313 - 3s - loss: 0.9924 - accuracy: 0.6629 - val_loss: 0.9214 - val_accuracy: 0.6932 - 3s/epoch - 10ms/step
# Epoch 7/10
# 313/313 - 3s - loss: 0.9467 - accuracy: 0.6806 - val_loss: 0.9087 - val_accuracy: 0.7004 - 3s/epoch - 11ms/step
# Epoch 8/10
# 313/313 - 3s - loss: 0.9020 - accuracy: 0.6963 - val_loss: 0.8579 - val_accuracy: 0.7200 - 3s/epoch - 10ms/step
# Epoch 9/10
# 313/313 - 3s - loss: 0.8639 - accuracy: 0.7066 - val_loss: 0.8251 - val_accuracy: 0.7264 - 3s/epoch - 10ms/step
# Epoch 10/10
# 313/313 - 3s - loss: 0.8397 - accuracy: 0.7164 - val_loss: 0.8193 - val_accuracy: 0.7270 - 3s/epoch - 10ms/step
# Epoch 1/10
# 313/313 - 4s - loss: 1.8028 - accuracy: 0.3539 - val_loss: 1.4997 - val_accuracy: 0.4648 - 4s/epoch - 13ms/step
# Epoch 2/10
# 313/313 - 3s - loss: 1.3826 - accuracy: 0.5122 - val_loss: 1.2420 - val_accuracy: 0.5610 - 3s/epoch - 10ms/step
# Epoch 3/10
# 313/313 - 3s - loss: 1.2184 - accuracy: 0.5784 - val_loss: 1.0885 - val_accuracy: 0.6300 - 3s/epoch - 11ms/step
# Epoch 4/10
# 313/313 - 3s - loss: 1.1141 - accuracy: 0.6177 - val_loss: 1.1046 - val_accuracy: 0.6199 - 3s/epoch - 10ms/step
# Epoch 5/10
# 313/313 - 3s - loss: 1.0358 - accuracy: 0.6489 - val_loss: 0.9549 - val_accuracy: 0.6749 - 3s/epoch - 10ms/step
# Epoch 6/10
# 313/313 - 3s - loss: 0.9742 - accuracy: 0.6701 - val_loss: 0.9241 - val_accuracy: 0.6865 - 3s/epoch - 10ms/step
# Epoch 7/10
# 313/313 - 3s - loss: 0.9196 - accuracy: 0.6866 - val_loss: 0.8668 - val_accuracy: 0.7113 - 3s/epoch - 10ms/step
# Epoch 8/10
# 313/313 - 3s - loss: 0.8817 - accuracy: 0.7024 - val_loss: 0.8334 - val_accuracy: 0.7212 - 3s/epoch - 11ms/step
# Epoch 9/10
# 313/313 - 3s - loss: 0.8396 - accuracy: 0.7183 - val_loss: 0.7999 - val_accuracy: 0.7336 - 3s/epoch - 11ms/step
# Epoch 10/10
# 313/313 - 3s - loss: 0.8106 - accuracy: 0.7271 - val_loss: 0.7908 - val_accuracy: 0.7378 - 3s/epoch - 11ms/step
# Epoch 1/10
# 313/313 - 4s - loss: 1.7777 - accuracy: 0.3644 - val_loss: 1.4579 - val_accuracy: 0.4797 - 4s/epoch - 14ms/step
# Epoch 2/10
# 313/313 - 3s - loss: 1.4241 - accuracy: 0.4945 - val_loss: 1.2883 - val_accuracy: 0.5498 - 3s/epoch - 11ms/step
# Epoch 3/10
# 313/313 - 3s - loss: 1.2800 - accuracy: 0.5539 - val_loss: 1.1772 - val_accuracy: 0.5884 - 3s/epoch - 11ms/step
# Epoch 4/10
# 313/313 - 3s - loss: 1.1801 - accuracy: 0.5955 - val_loss: 1.0426 - val_accuracy: 0.6459 - 3s/epoch - 10ms/step
# Epoch 5/10
# 313/313 - 3s - loss: 1.0864 - accuracy: 0.6288 - val_loss: 0.9997 - val_accuracy: 0.6579 - 3s/epoch - 10ms/step
# Epoch 6/10
# 313/313 - 3s - loss: 1.0169 - accuracy: 0.6528 - val_loss: 0.9320 - val_accuracy: 0.6827 - 3s/epoch - 11ms/step
# Epoch 7/10
# 313/313 - 3s - loss: 0.9640 - accuracy: 0.6730 - val_loss: 0.8703 - val_accuracy: 0.7034 - 3s/epoch - 11ms/step
# Epoch 8/10
# 313/313 - 3s - loss: 0.9191 - accuracy: 0.6886 - val_loss: 0.8439 - val_accuracy: 0.7155 - 3s/epoch - 10ms/step
# Epoch 9/10
# 313/313 - 3s - loss: 0.8779 - accuracy: 0.7028 - val_loss: 0.8213 - val_accuracy: 0.7249 - 3s/epoch - 11ms/step
# Epoch 10/10
# 313/313 - 3s - loss: 0.8455 - accuracy: 0.7134 - val_loss: 0.8548 - val_accuracy: 0.7069 - 3s/epoch - 10ms/step
# Epoch 1/10
# 313/313 - 4s - loss: 1.8139 - accuracy: 0.3525 - val_loss: 1.4942 - val_accuracy: 0.4688 - 4s/epoch - 13ms/step
# Epoch 2/10
# 313/313 - 3s - loss: 1.4449 - accuracy: 0.4864 - val_loss: 1.3161 - val_accuracy: 0.5422 - 3s/epoch - 11ms/step
# Epoch 3/10
# 313/313 - 3s - loss: 1.2934 - accuracy: 0.5465 - val_loss: 1.1586 - val_accuracy: 0.5987 - 3s/epoch - 11ms/step
# Epoch 4/10
# 313/313 - 3s - loss: 1.1763 - accuracy: 0.5935 - val_loss: 1.0486 - val_accuracy: 0.6412 - 3s/epoch - 10ms/step
# Epoch 5/10
# 313/313 - 3s - loss: 1.0793 - accuracy: 0.6302 - val_loss: 1.0060 - val_accuracy: 0.6569 - 3s/epoch - 10ms/step
# Epoch 6/10
# 313/313 - 3s - loss: 1.0145 - accuracy: 0.6547 - val_loss: 0.9549 - val_accuracy: 0.6735 - 3s/epoch - 10ms/step
# Epoch 7/10
# 313/313 - 3s - loss: 0.9590 - accuracy: 0.6743 - val_loss: 0.8826 - val_accuracy: 0.6997 - 3s/epoch - 11ms/step
# Epoch 8/10
# 313/313 - 3s - loss: 0.9070 - accuracy: 0.6909 - val_loss: 0.8561 - val_accuracy: 0.7146 - 3s/epoch - 10ms/step
# Epoch 9/10
# 313/313 - 3s - loss: 0.8785 - accuracy: 0.7032 - val_loss: 0.8405 - val_accuracy: 0.7155 - 3s/epoch - 10ms/step
# Epoch 10/10
# 313/313 - 3s - loss: 0.8381 - accuracy: 0.7197 - val_loss: 0.8596 - val_accuracy: 0.7148 - 3s/epoch - 11ms/step
# Epoch 1/10
# 313/313 - 4s - loss: 1.8043 - accuracy: 0.3539 - val_loss: 1.4982 - val_accuracy: 0.4709 - 4s/epoch - 14ms/step
# Epoch 2/10
# 313/313 - 3s - loss: 1.4031 - accuracy: 0.5038 - val_loss: 1.2390 - val_accuracy: 0.5649 - 3s/epoch - 10ms/step
# Epoch 3/10
# 313/313 - 3s - loss: 1.2170 - accuracy: 0.5775 - val_loss: 1.1272 - val_accuracy: 0.6161 - 3s/epoch - 10ms/step
# Epoch 4/10
# 313/313 - 3s - loss: 1.1133 - accuracy: 0.6161 - val_loss: 0.9955 - val_accuracy: 0.6635 - 3s/epoch - 10ms/step
# Epoch 5/10
# 313/313 - 3s - loss: 1.0336 - accuracy: 0.6476 - val_loss: 0.9844 - val_accuracy: 0.6663 - 3s/epoch - 11ms/step
# Epoch 6/10
# 313/313 - 3s - loss: 0.9722 - accuracy: 0.6697 - val_loss: 0.8905 - val_accuracy: 0.7010 - 3s/epoch - 11ms/step
# Epoch 7/10
# 313/313 - 3s - loss: 0.9289 - accuracy: 0.6874 - val_loss: 0.8666 - val_accuracy: 0.7111 - 3s/epoch - 10ms/step
# Epoch 8/10
# 313/313 - 3s - loss: 0.8785 - accuracy: 0.7039 - val_loss: 0.8456 - val_accuracy: 0.7201 - 3s/epoch - 10ms/step
# Epoch 9/10
# 313/313 - 3s - loss: 0.8469 - accuracy: 0.7143 - val_loss: 0.8224 - val_accuracy: 0.7280 - 3s/epoch - 10ms/step
# Epoch 10/10
# 313/313 - 3s - loss: 0.8109 - accuracy: 0.7269 - val_loss: 0.7912 - val_accuracy: 0.7355 - 3s/epoch - 10ms/step
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# 391/391 - 5s - loss: 1.5293 - accuracy: 0.4482 - val_loss: 1.2557 - val_accuracy: 0.5574 - 5s/epoch - 13ms/step
# Epoch 2/10
# 391/391 - 5s - loss: 1.1024 - accuracy: 0.6118 - val_loss: 1.0254 - val_accuracy: 0.6390 - 5s/epoch - 12ms/step
# Epoch 3/10
# 391/391 - 4s - loss: 0.8980 - accuracy: 0.6866 - val_loss: 0.8703 - val_accuracy: 0.6925 - 4s/epoch - 11ms/step
# Epoch 4/10
# 391/391 - 5s - loss: 0.7561 - accuracy: 0.7358 - val_loss: 0.8167 - val_accuracy: 0.7182 - 5s/epoch - 12ms/step
# Epoch 5/10
# 391/391 - 5s - loss: 0.6342 - accuracy: 0.7794 - val_loss: 0.7891 - val_accuracy: 0.7315 - 5s/epoch - 12ms/step
# Epoch 6/10
# 391/391 - 5s - loss: 0.5388 - accuracy: 0.8115 - val_loss: 0.7395 - val_accuracy: 0.7465 - 5s/epoch - 12ms/step
# Epoch 7/10
# 391/391 - 5s - loss: 0.4416 - accuracy: 0.8467 - val_loss: 0.8476 - val_accuracy: 0.7322 - 5s/epoch - 12ms/step
# Epoch 8/10
# 391/391 - 5s - loss: 0.3438 - accuracy: 0.8792 - val_loss: 0.8346 - val_accuracy: 0.7444 - 5s/epoch - 12ms/step
# Epoch 9/10
# 391/391 - 5s - loss: 0.2518 - accuracy: 0.9111 - val_loss: 0.9357 - val_accuracy: 0.7322 - 5s/epoch - 12ms/step
# Epoch 10/10
# 391/391 - 5s - loss: 0.1995 - accuracy: 0.9300 - val_loss: 1.0137 - val_accuracy: 0.7405 - 5s/epoch - 12ms/step
# Epoch 1/10
# 391/391 - 5s - loss: 1.4955 - accuracy: 0.4566 - val_loss: 1.2437 - val_accuracy: 0.5523 - 5s/epoch - 13ms/step
# Epoch 2/10
# 391/391 - 4s - loss: 1.0737 - accuracy: 0.6209 - val_loss: 0.9521 - val_accuracy: 0.6697 - 4s/epoch - 11ms/step
# Epoch 3/10
# 391/391 - 4s - loss: 0.8657 - accuracy: 0.6963 - val_loss: 0.8652 - val_accuracy: 0.6945 - 4s/epoch - 11ms/step
# Epoch 4/10
# 391/391 - 5s - loss: 0.7232 - accuracy: 0.7499 - val_loss: 0.8100 - val_accuracy: 0.7177 - 5s/epoch - 12ms/step
# Epoch 5/10
# 391/391 - 5s - loss: 0.6142 - accuracy: 0.7873 - val_loss: 0.7616 - val_accuracy: 0.7338 - 5s/epoch - 12ms/step
# Epoch 6/10
# 391/391 - 5s - loss: 0.5155 - accuracy: 0.8192 - val_loss: 0.7443 - val_accuracy: 0.7435 - 5s/epoch - 12ms/step
# Epoch 7/10
# 391/391 - 4s - loss: 0.4090 - accuracy: 0.8586 - val_loss: 0.7959 - val_accuracy: 0.7433 - 4s/epoch - 11ms/step
# Epoch 8/10
# 391/391 - 5s - loss: 0.3236 - accuracy: 0.8866 - val_loss: 0.8570 - val_accuracy: 0.7365 - 5s/epoch - 12ms/step
# Epoch 9/10
# 391/391 - 4s - loss: 0.2382 - accuracy: 0.9170 - val_loss: 0.9359 - val_accuracy: 0.7453 - 4s/epoch - 11ms/step
# Epoch 10/10
# 391/391 - 4s - loss: 0.1696 - accuracy: 0.9413 - val_loss: 1.0144 - val_accuracy: 0.7511 - 4s/epoch - 11ms/step
# Epoch 1/10
# 391/391 - 5s - loss: 1.5309 - accuracy: 0.4438 - val_loss: 1.2004 - val_accuracy: 0.5650 - 5s/epoch - 13ms/step
# Epoch 2/10
# 391/391 - 5s - loss: 1.0884 - accuracy: 0.6162 - val_loss: 1.0545 - val_accuracy: 0.6273 - 5s/epoch - 12ms/step
# Epoch 3/10
# 391/391 - 4s - loss: 0.8826 - accuracy: 0.6907 - val_loss: 0.8782 - val_accuracy: 0.6946 - 4s/epoch - 11ms/step
# Epoch 4/10
# 391/391 - 5s - loss: 0.7489 - accuracy: 0.7366 - val_loss: 0.8352 - val_accuracy: 0.7059 - 5s/epoch - 12ms/step
# Epoch 5/10
# 391/391 - 4s - loss: 0.6439 - accuracy: 0.7749 - val_loss: 0.7686 - val_accuracy: 0.7360 - 4s/epoch - 11ms/step
# Epoch 6/10
# 391/391 - 5s - loss: 0.5555 - accuracy: 0.8061 - val_loss: 0.7599 - val_accuracy: 0.7435 - 5s/epoch - 12ms/step
# Epoch 7/10
# 391/391 - 4s - loss: 0.4683 - accuracy: 0.8365 - val_loss: 0.7815 - val_accuracy: 0.7357 - 4s/epoch - 11ms/step
# Epoch 8/10
# 391/391 - 4s - loss: 0.3875 - accuracy: 0.8630 - val_loss: 0.8017 - val_accuracy: 0.7451 - 4s/epoch - 11ms/step
# Epoch 9/10
# 391/391 - 4s - loss: 0.3057 - accuracy: 0.8925 - val_loss: 0.9159 - val_accuracy: 0.7389 - 4s/epoch - 11ms/step
# Epoch 10/10
# 391/391 - 4s - loss: 0.2332 - accuracy: 0.9173 - val_loss: 0.9480 - val_accuracy: 0.7406 - 4s/epoch - 11ms/step
# Epoch 1/10
# 391/391 - 5s - loss: 1.5278 - accuracy: 0.4424 - val_loss: 1.2551 - val_accuracy: 0.5491 - 5s/epoch - 13ms/step
# Epoch 2/10
# 391/391 - 4s - loss: 1.1147 - accuracy: 0.6048 - val_loss: 0.9999 - val_accuracy: 0.6491 - 4s/epoch - 11ms/step
# Epoch 3/10
# 391/391 - 5s - loss: 0.9107 - accuracy: 0.6798 - val_loss: 0.8699 - val_accuracy: 0.6952 - 5s/epoch - 12ms/step
# Epoch 4/10
# 391/391 - 4s - loss: 0.7745 - accuracy: 0.7301 - val_loss: 0.7751 - val_accuracy: 0.7291 - 4s/epoch - 11ms/step
# Epoch 5/10
# 391/391 - 4s - loss: 0.6752 - accuracy: 0.7649 - val_loss: 0.7609 - val_accuracy: 0.7303 - 4s/epoch - 11ms/step
# Epoch 6/10
# 391/391 - 4s - loss: 0.5918 - accuracy: 0.7935 - val_loss: 0.7550 - val_accuracy: 0.7412 - 4s/epoch - 11ms/step
# Epoch 7/10
# 391/391 - 5s - loss: 0.5138 - accuracy: 0.8215 - val_loss: 0.7830 - val_accuracy: 0.7425 - 5s/epoch - 12ms/step
# Epoch 8/10
# 391/391 - 4s - loss: 0.4347 - accuracy: 0.8477 - val_loss: 0.8035 - val_accuracy: 0.7434 - 4s/epoch - 11ms/step
# Epoch 9/10
# 391/391 - 4s - loss: 0.3575 - accuracy: 0.8745 - val_loss: 0.7880 - val_accuracy: 0.7552 - 4s/epoch - 11ms/step
# Epoch 10/10
# 391/391 - 5s - loss: 0.2859 - accuracy: 0.8985 - val_loss: 0.9198 - val_accuracy: 0.7369 - 5s/epoch - 12ms/step
# Epoch 1/10
# 391/391 - 6s - loss: 1.5334 - accuracy: 0.4414 - val_loss: 1.2915 - val_accuracy: 0.5344 - 6s/epoch - 14ms/step
# Epoch 2/10
# 391/391 - 5s - loss: 1.1143 - accuracy: 0.6030 - val_loss: 1.0605 - val_accuracy: 0.6277 - 5s/epoch - 12ms/step
# Epoch 3/10
# 391/391 - 5s - loss: 0.9233 - accuracy: 0.6753 - val_loss: 0.8946 - val_accuracy: 0.6925 - 5s/epoch - 12ms/step
# Epoch 4/10
# 391/391 - 4s - loss: 0.7877 - accuracy: 0.7252 - val_loss: 0.8650 - val_accuracy: 0.7075 - 4s/epoch - 11ms/step
# Epoch 5/10
# 391/391 - 5s - loss: 0.6779 - accuracy: 0.7629 - val_loss: 0.7694 - val_accuracy: 0.7333 - 5s/epoch - 12ms/step
# Epoch 6/10
# 391/391 - 4s - loss: 0.5910 - accuracy: 0.7930 - val_loss: 0.7572 - val_accuracy: 0.7471 - 4s/epoch - 11ms/step
# Epoch 7/10
# 391/391 - 4s - loss: 0.5047 - accuracy: 0.8240 - val_loss: 0.7584 - val_accuracy: 0.7493 - 4s/epoch - 11ms/step
# Epoch 8/10
# 391/391 - 4s - loss: 0.4178 - accuracy: 0.8546 - val_loss: 0.8011 - val_accuracy: 0.7408 - 4s/epoch - 11ms/step
# Epoch 9/10
# 391/391 - 5s - loss: 0.3422 - accuracy: 0.8787 - val_loss: 0.8365 - val_accuracy: 0.7393 - 5s/epoch - 12ms/step
# Epoch 10/10
# 391/391 - 5s - loss: 0.2697 - accuracy: 0.9051 - val_loss: 0.9457 - val_accuracy: 0.7410 - 5s/epoch - 12ms/step
# Epoch 1/10
# 391/391 - 5s - loss: 1.6074 - accuracy: 0.4380 - val_loss: 1.2919 - val_accuracy: 0.5533 - 5s/epoch - 13ms/step
# Epoch 2/10
# 391/391 - 4s - loss: 1.1918 - accuracy: 0.5921 - val_loss: 1.1392 - val_accuracy: 0.6072 - 4s/epoch - 11ms/step
# Epoch 3/10
# 391/391 - 5s - loss: 1.0328 - accuracy: 0.6490 - val_loss: 1.0411 - val_accuracy: 0.6525 - 5s/epoch - 12ms/step
# Epoch 4/10
# 391/391 - 4s - loss: 0.9070 - accuracy: 0.6954 - val_loss: 0.9277 - val_accuracy: 0.6844 - 4s/epoch - 11ms/step
# Epoch 5/10
# 391/391 - 5s - loss: 0.8028 - accuracy: 0.7328 - val_loss: 0.8732 - val_accuracy: 0.7046 - 5s/epoch - 12ms/step
# Epoch 6/10
# 391/391 - 5s - loss: 0.7202 - accuracy: 0.7608 - val_loss: 0.8403 - val_accuracy: 0.7155 - 5s/epoch - 12ms/step
# Epoch 7/10
# 391/391 - 4s - loss: 0.6359 - accuracy: 0.7915 - val_loss: 0.8003 - val_accuracy: 0.7388 - 4s/epoch - 11ms/step
# Epoch 8/10
# 391/391 - 4s - loss: 0.5678 - accuracy: 0.8150 - val_loss: 0.8108 - val_accuracy: 0.7378 - 4s/epoch - 11ms/step
# Epoch 9/10
# 391/391 - 5s - loss: 0.4989 - accuracy: 0.8399 - val_loss: 0.8432 - val_accuracy: 0.7397 - 5s/epoch - 12ms/step
# Epoch 10/10
# 391/391 - 5s - loss: 0.4319 - accuracy: 0.8633 - val_loss: 0.8816 - val_accuracy: 0.7329 - 5s/epoch - 12ms/step
# Epoch 1/10
# 391/391 - 5s - loss: 1.6146 - accuracy: 0.4330 - val_loss: 1.2966 - val_accuracy: 0.5489 - 5s/epoch - 13ms/step
# Epoch 2/10
# 391/391 - 4s - loss: 1.2083 - accuracy: 0.5844 - val_loss: 1.1019 - val_accuracy: 0.6242 - 4s/epoch - 11ms/step
# Epoch 3/10
# 391/391 - 5s - loss: 1.0156 - accuracy: 0.6569 - val_loss: 1.0175 - val_accuracy: 0.6579 - 5s/epoch - 12ms/step
# Epoch 4/10
# 391/391 - 5s - loss: 0.8983 - accuracy: 0.6968 - val_loss: 0.9741 - val_accuracy: 0.6713 - 5s/epoch - 12ms/step
# Epoch 5/10
# 391/391 - 5s - loss: 0.7814 - accuracy: 0.7402 - val_loss: 0.8166 - val_accuracy: 0.7312 - 5s/epoch - 12ms/step
# Epoch 6/10
# 391/391 - 5s - loss: 0.7002 - accuracy: 0.7662 - val_loss: 0.8119 - val_accuracy: 0.7327 - 5s/epoch - 12ms/step
# Epoch 7/10
# 391/391 - 4s - loss: 0.6352 - accuracy: 0.7887 - val_loss: 0.7957 - val_accuracy: 0.7361 - 4s/epoch - 11ms/step
# Epoch 8/10
# 391/391 - 5s - loss: 0.5542 - accuracy: 0.8182 - val_loss: 0.8099 - val_accuracy: 0.7410 - 5s/epoch - 12ms/step
# Epoch 9/10
# 391/391 - 5s - loss: 0.4851 - accuracy: 0.8436 - val_loss: 0.8330 - val_accuracy: 0.7386 - 5s/epoch - 12ms/step
# Epoch 10/10
# 391/391 - 5s - loss: 0.4164 - accuracy: 0.8700 - val_loss: 0.8584 - val_accuracy: 0.7455 - 5s/epoch - 12ms/step
# Epoch 1/10

# %%
print(np.array(cnn_000).mean())
print(np.array(cnn_001).mean())
print(np.array(cnn_010).mean())
print(np.array(cnn_011).mean())
print(np.array(cnn_100).mean())
print(np.array(cnn_101).mean())
print(np.array(cnn_111).mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e9c4e6a2132a> in <module>
# ----> 1 print(np.array(cnn_000).mean())
#       2 print(np.array(cnn_001).mean())
#       3 print(np.array(cnn_010).mean())
#       4 print(np.array(cnn_011).mean())
#       5 print(np.array(cnn_100).mean())
#
# NameError: name 'np' is not defined

# %%
import matplotlib.pyplot as plt
sns.boxplot(data = [cnn_001,cnn_010,cnn_011,cnn_100,cnn_101,cnn_111])
# plt.boxplot(data = [cnn_001,cnn_010,cnn_011,cnn_100,cnn_101,cnn_111])

# %%
# 세션 유지하는 방법
# F12번 키를 누르고 
#콘솔창에서 아래 코드를 입력하고 엔터

function ClickConnect() {
    var buttons = document.querySelectorAll("colab-dialog.yes-no-dialog paper-button#cancel"); 
    buttons.forEach(function(btn) { 
        btn.click(); 
    }); 
    console.log("1분마다 자동 재연결"); 
    document.querySelector("colab-toolbar-button#connect").click(); 
} 
setInterval(ClickConnect,1000*60);
